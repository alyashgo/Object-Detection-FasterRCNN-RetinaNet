# %% [markdown]
# # ELL793 Assignment 4
# **Object Detection using RetinaNet with vanilla CE Loss** <br>
# Abhinava Sikdar 2017MT01724 <br>
# Yashank Singh 2017MT10756

# %%
import torch
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

print('Is CUDA available', torch.cuda.is_available())
print('Torch', torch.__version__, 'CUDA', torch.version.cuda)
print('Device:', torch.device('cuda:0'))
#https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html
# Out:
# Is CUDA available True
# Torch 1.7.0+cu101 CUDA 10.1
# Device: cuda:0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#https://colab.research.google.com/github/pytorch/vision/blob/temp-tutorial/tutorials/torchvision_finetuning_instance_segmentation.ipynb#scrollTo=-WXLwePV5ieP
# !git clone https://github.com/pytorch/vision.git
# !cd vision
# !git checkout v0.3.0

# !cp /content/vision/references/detection/utils.py ../usr/lib/python3.6
# !cp /content/vision/references/detection/transforms.py ../usr/lib/python3.6
# !cp /content/vision/references/detection/coco_eval.py ../usr/lib/python3.6
# !cp /content/vision/references/detection/engine.py ../usr/lib/python3.6
# !cp /content/vision/references/detection/coco_utils.py ../usr/lib/python3.6
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 12255 (delta 2), reused 1 (delta 0), pack-reused 12249
# Receiving objects: 100% (12255/12255), 13.46 MiB | 23.57 MiB/s, done.
# Resolving deltas: 100% (8555/8555), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
dev=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#https://github.com/pytorch/vision/blob/master/references/detection/engine.py
#https://github.com/pytorch/vision/blob/master/references/detection/utils.py
from engine import evaluate,train_one_epoch
import utils
import transforms as T

# %% [markdown]
# ## Datset and Loaders

# %%
def return_class(class_name):
    classes=['person','bird', 'cat', 'cow', 'dog', 'horse', 'sheep', 'aeroplane', 'bicycle', 'boat', 'bus', 'car', 'motorbike', 'train', 'bottle', 'chair', 'diningtable', 'pottedplant', 'sofa', 'tvmonitor']
    return classes.index(class_name)

# %%
class VOC_Dataset(torch.utils.data.Dataset):
  def __init__(self, dataset, transforms=None):
    self.transforms = transforms
    self.dataset=dataset
  
  def __getitem__(self,ind):
    boxes=[]
    names=[]
    img,dic =self.dataset[ind]
    for i in range(len(dic['annotation']['object'])):
      xmax=int(dic['annotation']['object'][i]['bndbox']['xmax'])
      xmin=int(dic['annotation']['object'][i]['bndbox']['xmin'])
      ymax=int(dic['annotation']['object'][i]['bndbox']['ymax'])
      ymin=int(dic['annotation']['object'][i]['bndbox']['ymin'])
      boxes.append([xmin, ymin, xmax, ymax])
      names.append(return_class(dic['annotation']['object'][i]['name']))
    
    target={}
    target['boxes']=torch.as_tensor(boxes,dtype=torch.float32)
    target['labels']=torch.as_tensor(names,dtype=torch.int64)
    target['image_id'] = torch.tensor(int(dic['annotation']['source']['flickrid']),dtype=torch.int64)
    target['area']=(target['boxes'][:, 3] - target['boxes'][:, 1]) * (target['boxes'][:, 2] - target['boxes'][:, 0])
    target['iscrowd']=torch.zeros((len(dic['annotation']['object']),), dtype=torch.int64)
    return img,target

  def __len__(self):
    return len(self.dataset)

# %%
data_path='../data/'
voc_train_tem=datasets.VOCDetection(data_path, year='2007', image_set='train', download=True, transform=transforms.ToTensor())
voc_test_tem=datasets.VOCDetection(data_path, year='2007', image_set='trainval',download=True, transform=transforms.ToTensor())
# Out:
# Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar to ../data/VOCtrainval_06-Nov-2007.tar
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Using downloaded and verified file: ../data/VOCtrainval_06-Nov-2007.tar

# %%
voc_train=VOC_Dataset(dataset=voc_train_tem)
voc_test=VOC_Dataset(dataset=voc_test_tem)

# %%
print(len(voc_test))
img,lab=voc_test_tem[14]
plt.imshow(img.permute(1,2,0))
# Out:
# 5011

# %%
train_loader=torch.utils.data.DataLoader(voc_train,batch_size=2,shuffle=True, num_workers=0,collate_fn=utils.collate_fn)
test_loader=torch.utils.data.DataLoader(voc_test,batch_size=2,shuffle=False, num_workers=0,collate_fn=utils.collate_fn)

# %% [markdown]
# ## Model With Cross Entropy Loss

# %%
import torch
import torch.nn.functional as F


def ce_loss(
    inputs,
    targets,
    reduction: str = "none",
):
    """
    Original implementation from https://github.com/facebookresearch/fvcore/blob/master/fvcore/nn/focal_loss.py .
    Loss used in RetinaNet for dense detection: https://arxiv.org/abs/1708.02002.
    Args:
        inputs: A float tensor of arbitrary shape.
                The predictions for each example.
        targets: A float tensor with the same shape as inputs. Stores the binary
                 classification label for each element in inputs
                (0 for the negative class and 1 for the positive class).
        reduction: 'none' | 'mean' | 'sum'
                 'none': No reduction will be applied to the output.
                 'mean': The output will be averaged.
                 'sum': The output will be summed.
    Returns:
        Loss tensor with the reduction option applied.
    """
    p = torch.sigmoid(inputs)
    ce_loss = F.binary_cross_entropy_with_logits(
        inputs, targets, reduction="none"
    )
    loss = ce_loss
    if reduction == "mean":
        loss = loss.mean()
    elif reduction == "sum":
        loss = loss.sum()

    return loss

# %%
import math
from collections import OrderedDict
import warnings

import torch
import torch.nn as nn
from torch import Tensor
from torch.jit.annotations import Dict, List, Tuple

from torchvision.models.utils import load_state_dict_from_url

from torchvision.models.detection import _utils as det_utils
from torchvision.models.detection.anchor_utils import AnchorGenerator
from torchvision.models.detection.transform import GeneralizedRCNNTransform
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.ops.feature_pyramid_network import LastLevelP6P7
from torchvision.ops import boxes as box_ops


__all__ = [
    "RetinaNet", "retinanet_resnet50_fpn",
]


def _sum(x: List[Tensor]) -> Tensor:
    res = x[0]
    for i in x[1:]:
        res = res + i
    return res


class RetinaNetHead(nn.Module):
    """
    A regression and classification head for use in RetinaNet.

    Arguments:
        in_channels (int): number of channels of the input feature
        num_anchors (int): number of anchors to be predicted
        num_classes (int): number of classes to be predicted
    """

    def __init__(self, in_channels, num_anchors, num_classes):
        super().__init__()
        self.classification_head = RetinaNetClassificationHead(in_channels, num_anchors, num_classes)
        self.regression_head = RetinaNetRegressionHead(in_channels, num_anchors)

    def compute_loss(self, targets, head_outputs, anchors, matched_idxs):
        # type: (List[Dict[str, Tensor]], Dict[str, Tensor], List[Tensor], List[Tensor]) -> Dict[str, Tensor]
        return {
            'classification': self.classification_head.compute_loss(targets, head_outputs, matched_idxs),
            'bbox_regression': self.regression_head.compute_loss(targets, head_outputs, anchors, matched_idxs),
        }

    def forward(self, x):
        # type: (List[Tensor]) -> Dict[str, Tensor]
        return {
            'cls_logits': self.classification_head(x),
            'bbox_regression': self.regression_head(x)
        }


class RetinaNetClassificationHead(nn.Module):
    """
    A classification head for use in RetinaNet.

    Arguments:
        in_channels (int): number of channels of the input feature
        num_anchors (int): number of anchors to be predicted
        num_classes (int): number of classes to be predicted
    """

    def __init__(self, in_channels, num_anchors, num_classes, prior_probability=0.01):
        super().__init__()

        conv = []
        for _ in range(4):
            conv.append(nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1))
            conv.append(nn.ReLU())
        self.conv = nn.Sequential(*conv)

        for layer in self.conv.children():
            if isinstance(layer, nn.Conv2d):
                torch.nn.init.normal_(layer.weight, std=0.01)
                torch.nn.init.constant_(layer.bias, 0)

        self.cls_logits = nn.Conv2d(in_channels, num_anchors * num_classes, kernel_size=3, stride=1, padding=1)
        torch.nn.init.normal_(self.cls_logits.weight, std=0.01)
        torch.nn.init.constant_(self.cls_logits.bias, -math.log((1 - prior_probability) / prior_probability))

        self.num_classes = num_classes
        self.num_anchors = num_anchors

        # This is to fix using det_utils.Matcher.BETWEEN_THRESHOLDS in TorchScript.
        # TorchScript doesn't support class attributes.
        # https://github.com/pytorch/vision/pull/1697#issuecomment-630255584
        self.BETWEEN_THRESHOLDS = det_utils.Matcher.BETWEEN_THRESHOLDS

    def compute_loss(self, targets, head_outputs, matched_idxs):
        # type: (List[Dict[str, Tensor]], Dict[str, Tensor], List[Tensor]) -> Tensor
        losses = []

        cls_logits = head_outputs['cls_logits']

        for targets_per_image, cls_logits_per_image, matched_idxs_per_image in zip(targets, cls_logits, matched_idxs):
            # determine only the foreground
            foreground_idxs_per_image = matched_idxs_per_image >= 0
            num_foreground = foreground_idxs_per_image.sum()
            # no matched_idxs means there were no annotations in this image
            # TODO: enable support for images without annotations that works on distributed
            if False:  # matched_idxs_per_image.numel() == 0:
                gt_classes_target = torch.zeros_like(cls_logits_per_image)
                valid_idxs_per_image = torch.arange(cls_logits_per_image.shape[0])
            else:
                # create the target classification
                gt_classes_target = torch.zeros_like(cls_logits_per_image)
                gt_classes_target[
                    foreground_idxs_per_image,
                    targets_per_image['labels'][matched_idxs_per_image[foreground_idxs_per_image]]
                ] = 1.0

                # find indices for which anchors should be ignored
                valid_idxs_per_image = matched_idxs_per_image != self.BETWEEN_THRESHOLDS

            # compute the classification loss################################################CHANGES START HERE##################################################################################################
            losses.append(ce_loss(
                cls_logits_per_image[valid_idxs_per_image],
                gt_classes_target[valid_idxs_per_image],
                reduction='sum',
            ) / max(1, num_foreground))
            # compute the classification loss################################################CHANGES END HERE##################################################################################################

        return _sum(losses) / len(targets)

    def forward(self, x):
        # type: (List[Tensor]) -> Tensor
        all_cls_logits = []

        for features in x:
            cls_logits = self.conv(features)
            cls_logits = self.cls_logits(cls_logits)

            # Permute classification output from (N, A * K, H, W) to (N, HWA, K).
            N, _, H, W = cls_logits.shape
            cls_logits = cls_logits.view(N, -1, self.num_classes, H, W)
            cls_logits = cls_logits.permute(0, 3, 4, 1, 2)
            cls_logits = cls_logits.reshape(N, -1, self.num_classes)  # Size=(N, HWA, 4)

            all_cls_logits.append(cls_logits)

        return torch.cat(all_cls_logits, dim=1)


class RetinaNetRegressionHead(nn.Module):
    """
    A regression head for use in RetinaNet.

    Arguments:
        in_channels (int): number of channels of the input feature
        num_anchors (int): number of anchors to be predicted
    """
    __annotations__ = {
        'box_coder': det_utils.BoxCoder,
    }

    def __init__(self, in_channels, num_anchors):
        super().__init__()

        conv = []
        for _ in range(4):
            conv.append(nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1))
            conv.append(nn.ReLU())
        self.conv = nn.Sequential(*conv)

        self.bbox_reg = nn.Conv2d(in_channels, num_anchors * 4, kernel_size=3, stride=1, padding=1)
        torch.nn.init.normal_(self.bbox_reg.weight, std=0.01)
        torch.nn.init.zeros_(self.bbox_reg.bias)

        for layer in self.conv.children():
            if isinstance(layer, nn.Conv2d):
                torch.nn.init.normal_(layer.weight, std=0.01)
                torch.nn.init.zeros_(layer.bias)

        self.box_coder = det_utils.BoxCoder(weights=(1.0, 1.0, 1.0, 1.0))

    def compute_loss(self, targets, head_outputs, anchors, matched_idxs):
        # type: (List[Dict[str, Tensor]], Dict[str, Tensor], List[Tensor], List[Tensor]) -> Tensor
        losses = []

        bbox_regression = head_outputs['bbox_regression']

        for targets_per_image, bbox_regression_per_image, anchors_per_image, matched_idxs_per_image in \
                zip(targets, bbox_regression, anchors, matched_idxs):
            # no matched_idxs means there were no annotations in this image
            # TODO enable support for images without annotations with distributed support
            # if matched_idxs_per_image.numel() == 0:
            #     continue

            # get the targets corresponding GT for each proposal
            # NB: need to clamp the indices because we can have a single
            # GT in the image, and matched_idxs can be -2, which goes
            # out of bounds
            matched_gt_boxes_per_image = targets_per_image['boxes'][matched_idxs_per_image.clamp(min=0)]

            # determine only the foreground indices, ignore the rest
            foreground_idxs_per_image = matched_idxs_per_image >= 0
            num_foreground = foreground_idxs_per_image.sum()

            # select only the foreground boxes
            matched_gt_boxes_per_image = matched_gt_boxes_per_image[foreground_idxs_per_image, :]
            bbox_regression_per_image = bbox_regression_per_image[foreground_idxs_per_image, :]
            anchors_per_image = anchors_per_image[foreground_idxs_per_image, :]

            # compute the regression targets
            target_regression = self.box_coder.encode_single(matched_gt_boxes_per_image, anchors_per_image)

            # compute the loss
            losses.append(torch.nn.functional.l1_loss(
                bbox_regression_per_image,
                target_regression,
                size_average=False
            ) / max(1, num_foreground))

        return _sum(losses) / max(1, len(targets))

    def forward(self, x):
        # type: (List[Tensor]) -> Tensor
        all_bbox_regression = []

        for features in x:
            bbox_regression = self.conv(features)
            bbox_regression = self.bbox_reg(bbox_regression)

            # Permute bbox regression output from (N, 4 * A, H, W) to (N, HWA, 4).
            N, _, H, W = bbox_regression.shape
            bbox_regression = bbox_regression.view(N, -1, 4, H, W)
            bbox_regression = bbox_regression.permute(0, 3, 4, 1, 2)
            bbox_regression = bbox_regression.reshape(N, -1, 4)  # Size=(N, HWA, 4)

            all_bbox_regression.append(bbox_regression)

        return torch.cat(all_bbox_regression, dim=1)


class RetinaNet(nn.Module):
    """
    Implements RetinaNet.

    The input to the model is expected to be a list of tensors, each of shape [C, H, W], one for each
    image, and should be in 0-1 range. Different images can have different sizes.

    The behavior of the model changes depending if it is in training or evaluation mode.

    During training, the model expects both the input tensors, as well as a targets (list of dictionary),
    containing:
        - boxes (FloatTensor[N, 4]): the ground-truth boxes in [x1, y1, x2, y2] format, with values
          between 0 and H and 0 and W
        - labels (Int64Tensor[N]): the class label for each ground-truth box

    The model returns a Dict[Tensor] during training, containing the classification and regression
    losses.

    During inference, the model requires only the input tensors, and returns the post-processed
    predictions as a List[Dict[Tensor]], one for each input image. The fields of the Dict are as
    follows:
        - boxes (FloatTensor[N, 4]): the predicted boxes in [x1, y1, x2, y2] format, with values between
          0 and H and 0 and W
        - labels (Int64Tensor[N]): the predicted labels for each image
        - scores (Tensor[N]): the scores for each prediction

    Arguments:
        backbone (nn.Module): the network used to compute the features for the model.
            It should contain an out_channels attribute, which indicates the number of output
            channels that each feature map has (and it should be the same for all feature maps).
            The backbone should return a single Tensor or an OrderedDict[Tensor].
        num_classes (int): number of output classes of the model (excluding the background).
        min_size (int): minimum size of the image to be rescaled before feeding it to the backbone
        max_size (int): maximum size of the image to be rescaled before feeding it to the backbone
        image_mean (Tuple[float, float, float]): mean values used for input normalization.
            They are generally the mean values of the dataset on which the backbone has been trained
            on
        image_std (Tuple[float, float, float]): std values used for input normalization.
            They are generally the std values of the dataset on which the backbone has been trained on
        anchor_generator (AnchorGenerator): module that generates the anchors for a set of feature
            maps.
        head (nn.Module): Module run on top of the feature pyramid.
            Defaults to a module containing a classification and regression module.
        score_thresh (float): Score threshold used for postprocessing the detections.
        nms_thresh (float): NMS threshold used for postprocessing the detections.
        detections_per_img (int): Number of best detections to keep after NMS.
        fg_iou_thresh (float): minimum IoU between the anchor and the GT box so that they can be
            considered as positive during training.
        bg_iou_thresh (float): maximum IoU between the anchor and the GT box so that they can be
            considered as negative during training.

    Example:

        >>> import torch
        >>> import torchvision
        >>> from torchvision.models.detection import RetinaNet
        >>> from torchvision.models.detection.anchor_utils import AnchorGenerator
        >>> # load a pre-trained model for classification and return
        >>> # only the features
        >>> backbone = torchvision.models.mobilenet_v2(pretrained=True).features
        >>> # RetinaNet needs to know the number of
        >>> # output channels in a backbone. For mobilenet_v2, it's 1280
        >>> # so we need to add it here
        >>> backbone.out_channels = 1280
        >>>
        >>> # let's make the network generate 5 x 3 anchors per spatial
        >>> # location, with 5 different sizes and 3 different aspect
        >>> # ratios. We have a Tuple[Tuple[int]] because each feature
        >>> # map could potentially have different sizes and
        >>> # aspect ratios
        >>> anchor_generator = AnchorGenerator(
        >>>     sizes=((32, 64, 128, 256, 512),),
        >>>     aspect_ratios=((0.5, 1.0, 2.0),)
        >>> )
        >>>
        >>> # put the pieces together inside a RetinaNet model
        >>> model = RetinaNet(backbone,
        >>>                   num_classes=2,
        >>>                   anchor_generator=anchor_generator)
        >>> model.eval()
        >>> x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
        >>> predictions = model(x)
    """
    __annotations__ = {
        'box_coder': det_utils.BoxCoder,
        'proposal_matcher': det_utils.Matcher,
    }

    def __init__(self, backbone, num_classes,
                 # transform parameters
                 min_size=800, max_size=1333,
                 image_mean=None, image_std=None,
                 # Anchor parameters
                 anchor_generator=None, head=None,
                 proposal_matcher=None,
                 score_thresh=0.05,
                 nms_thresh=0.5,
                 detections_per_img=300,
                 fg_iou_thresh=0.5, bg_iou_thresh=0.4):
        super().__init__()

        if not hasattr(backbone, "out_channels"):
            raise ValueError(
                "backbone should contain an attribute out_channels "
                "specifying the number of output channels (assumed to be the "
                "same for all the levels)")
        self.backbone = backbone

        assert isinstance(anchor_generator, (AnchorGenerator, type(None)))

        if anchor_generator is None:
            anchor_sizes = tuple((x, int(x * 2 ** (1.0 / 3)), int(x * 2 ** (2.0 / 3))) for x in [32, 64, 128, 256, 512])
            aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_sizes)
            anchor_generator = AnchorGenerator(
                anchor_sizes, aspect_ratios
            )
        self.anchor_generator = anchor_generator

        if head is None:
            head = RetinaNetHead(backbone.out_channels, anchor_generator.num_anchors_per_location()[0], num_classes)
        self.head = head

        if proposal_matcher is None:
            proposal_matcher = det_utils.Matcher(
                fg_iou_thresh,
                bg_iou_thresh,
                allow_low_quality_matches=True,
            )
        self.proposal_matcher = proposal_matcher

        self.box_coder = det_utils.BoxCoder(weights=(1.0, 1.0, 1.0, 1.0))

        if image_mean is None:
            image_mean = [0.485, 0.456, 0.406]
        if image_std is None:
            image_std = [0.229, 0.224, 0.225]
        self.transform = GeneralizedRCNNTransform(min_size, max_size, image_mean, image_std)

        self.score_thresh = score_thresh
        self.nms_thresh = nms_thresh
        self.detections_per_img = detections_per_img

        # used only on torchscript mode
        self._has_warned = False

    @torch.jit.unused
    def eager_outputs(self, losses, detections):
        # type: (Dict[str, Tensor], List[Dict[str, Tensor]]) -> Tuple[Dict[str, Tensor], List[Dict[str, Tensor]]]
        if self.training:
            return losses

        return detections

    def compute_loss(self, targets, head_outputs, anchors):
        # type: (List[Dict[str, Tensor]], Dict[str, Tensor], List[Tensor]) -> Dict[str, Tensor]
        matched_idxs = []
        for anchors_per_image, targets_per_image in zip(anchors, targets):
            if targets_per_image['boxes'].numel() == 0:
                matched_idxs.append(torch.empty((0,), dtype=torch.int32))
                continue

            match_quality_matrix = box_ops.box_iou(targets_per_image['boxes'], anchors_per_image)
            matched_idxs.append(self.proposal_matcher(match_quality_matrix))

        return self.head.compute_loss(targets, head_outputs, anchors, matched_idxs)

    def postprocess_detections(self, head_outputs, anchors, image_shapes):
        # type: (Dict[str, Tensor], List[Tensor], List[Tuple[int, int]]) -> List[Dict[str, Tensor]]
        # TODO: Merge this with roi_heads.RoIHeads.postprocess_detections ?

        class_logits = head_outputs.pop('cls_logits')
        box_regression = head_outputs.pop('bbox_regression')
        other_outputs = head_outputs

        device = class_logits.device
        num_classes = class_logits.shape[-1]

        scores = torch.sigmoid(class_logits)

        # create labels for each score
        labels = torch.arange(num_classes, device=device)
        labels = labels.view(1, -1).expand_as(scores)

        detections = torch.jit.annotate(List[Dict[str, Tensor]], [])

        for index, (box_regression_per_image, scores_per_image, labels_per_image, anchors_per_image, image_shape) in \
                enumerate(zip(box_regression, scores, labels, anchors, image_shapes)):

            boxes_per_image = self.box_coder.decode_single(box_regression_per_image, anchors_per_image)
            boxes_per_image = box_ops.clip_boxes_to_image(boxes_per_image, image_shape)

            other_outputs_per_image = [(k, v[index]) for k, v in other_outputs.items()]

            image_boxes = []
            image_scores = []
            image_labels = []
            image_other_outputs = torch.jit.annotate(Dict[str, List[Tensor]], {})

            for class_index in range(num_classes):
                # remove low scoring boxes
                inds = torch.gt(scores_per_image[:, class_index], self.score_thresh)
                boxes_per_class, scores_per_class, labels_per_class = \
                    boxes_per_image[inds], scores_per_image[inds, class_index], labels_per_image[inds, class_index]
                other_outputs_per_class = [(k, v[inds]) for k, v in other_outputs_per_image]

                # remove empty boxes
                keep = box_ops.remove_small_boxes(boxes_per_class, min_size=1e-2)
                boxes_per_class, scores_per_class, labels_per_class = \
                    boxes_per_class[keep], scores_per_class[keep], labels_per_class[keep]
                other_outputs_per_class = [(k, v[keep]) for k, v in other_outputs_per_class]

                # non-maximum suppression, independently done per class
                keep = box_ops.nms(boxes_per_class, scores_per_class, self.nms_thresh)

                # keep only topk scoring predictions
                keep = keep[:self.detections_per_img]
                boxes_per_class, scores_per_class, labels_per_class = \
                    boxes_per_class[keep], scores_per_class[keep], labels_per_class[keep]
                other_outputs_per_class = [(k, v[keep]) for k, v in other_outputs_per_class]

                image_boxes.append(boxes_per_class)
                image_scores.append(scores_per_class)
                image_labels.append(labels_per_class)

                for k, v in other_outputs_per_class:
                    if k not in image_other_outputs:
                        image_other_outputs[k] = []
                    image_other_outputs[k].append(v)

            detections.append({
                'boxes': torch.cat(image_boxes, dim=0),
                'scores': torch.cat(image_scores, dim=0),
                'labels': torch.cat(image_labels, dim=0),
            })

            for k, v in image_other_outputs.items():
                detections[-1].update({k: torch.cat(v, dim=0)})

        return detections

    def forward(self, images, targets=None):
        # type: (List[Tensor], Optional[List[Dict[str, Tensor]]]) -> Tuple[Dict[str, Tensor], List[Dict[str, Tensor]]]
        """
        Arguments:
            images (list[Tensor]): images to be processed
            targets (list[Dict[Tensor]]): ground-truth boxes present in the image (optional)

        Returns:
            result (list[BoxList] or dict[Tensor]): the output from the model.
                During training, it returns a dict[Tensor] which contains the losses.
                During testing, it returns list[BoxList] contains additional fields
                like `scores`, `labels` and `mask` (for Mask R-CNN models).

        """
        if self.training and targets is None:
            raise ValueError("In training mode, targets should be passed")

        if self.training:
            assert targets is not None
            for target in targets:
                boxes = target["boxes"]
                if isinstance(boxes, torch.Tensor):
                    if len(boxes.shape) != 2 or boxes.shape[-1] != 4:
                        raise ValueError("Expected target boxes to be a tensor"
                                         "of shape [N, 4], got {:}.".format(
                                             boxes.shape))
                else:
                    raise ValueError("Expected target boxes to be of type "
                                     "Tensor, got {:}.".format(type(boxes)))

        # get the original image sizes
        original_image_sizes = torch.jit.annotate(List[Tuple[int, int]], [])
        for img in images:
            val = img.shape[-2:]
            assert len(val) == 2
            original_image_sizes.append((val[0], val[1]))

        # transform the input
        images, targets = self.transform(images, targets)

        # Check for degenerate boxes
        # TODO: Move this to a function
        if targets is not None:
            for target_idx, target in enumerate(targets):
                boxes = target["boxes"]
                degenerate_boxes = boxes[:, 2:] <= boxes[:, :2]
                if degenerate_boxes.any():
                    # print the first degenerate box
                    bb_idx = torch.where(degenerate_boxes.any(dim=1))[0][0]
                    degen_bb: List[float] = boxes[bb_idx].tolist()
                    raise ValueError("All bounding boxes should have positive height and width."
                                     " Found invalid box {} for target at index {}."
                                     .format(degen_bb, target_idx))

        # get the features from the backbone
        features = self.backbone(images.tensors)
        if isinstance(features, torch.Tensor):
            features = OrderedDict([('0', features)])

        # TODO: Do we want a list or a dict?
        features = list(features.values())

        # compute the retinanet heads outputs using the features
        head_outputs = self.head(features)

        # create the set of anchors
        anchors = self.anchor_generator(images, features)

        losses = {}
        detections = torch.jit.annotate(List[Dict[str, Tensor]], [])
        if self.training:
            assert targets is not None

            # compute the losses
            losses = self.compute_loss(targets, head_outputs, anchors)
        else:
            # compute the detections
            detections = self.postprocess_detections(head_outputs, anchors, images.image_sizes)
            detections = self.transform.postprocess(detections, images.image_sizes, original_image_sizes)

        if torch.jit.is_scripting():
            if not self._has_warned:
                warnings.warn("RetinaNet always returns a (Losses, Detections) tuple in scripting")
                self._has_warned = True
            return (losses, detections)
        return self.eager_outputs(losses, detections)

model_urls = {
    'retinanet_resnet50_fpn_coco':
        'https://download.pytorch.org/models/retinanet_resnet50_fpn_coco-eeacb38b.pth',
}


def retinanet_resnet50_fpn(pretrained=False, progress=True,
                           num_classes=91, pretrained_backbone=True, **kwargs):
    """
    Constructs a RetinaNet model with a ResNet-50-FPN backbone.

    The input to the model is expected to be a list of tensors, each of shape ``[C, H, W]``, one for each
    image, and should be in ``0-1`` range. Different images can have different sizes.

    The behavior of the model changes depending if it is in training or evaluation mode.

    During training, the model expects both the input tensors, as well as a targets (list of dictionary),
    containing:
        - boxes (``FloatTensor[N, 4]``): the ground-truth boxes in ``[x1, y1, x2, y2]`` format, with values
          between ``0`` and ``H`` and ``0`` and ``W``
        - labels (``Int64Tensor[N]``): the class label for each ground-truth box

    The model returns a ``Dict[Tensor]`` during training, containing the classification and regression
    losses.

    During inference, the model requires only the input tensors, and returns the post-processed
    predictions as a ``List[Dict[Tensor]]``, one for each input image. The fields of the ``Dict`` are as
    follows:
        - boxes (``FloatTensor[N, 4]``): the predicted boxes in ``[x1, y1, x2, y2]`` format, with values between
          ``0`` and ``H`` and ``0`` and ``W``
        - labels (``Int64Tensor[N]``): the predicted labels for each image
        - scores (``Tensor[N]``): the scores or each prediction

    Example::

        >>> model = torchvision.models.detection.retinanet_resnet50_fpn(pretrained=True)
        >>> model.eval()
        >>> x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
        >>> predictions = model(x)

    Arguments:
        pretrained (bool): If True, returns a model pre-trained on COCO train2017
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    if pretrained:
        # no need to download the backbone if pretrained is set
        pretrained_backbone = False
    # skip P2 because it generates too many anchors (according to their paper)
    backbone = resnet_fpn_backbone('resnet50', pretrained_backbone,
                                   returned_layers=[2, 3, 4], extra_blocks=LastLevelP6P7(256, 256))
    model = RetinaNet(backbone, num_classes, **kwargs)
    if pretrained:
        state_dict = load_state_dict_from_url(model_urls['retinanet_resnet50_fpn_coco'],
                                              progress=progress)
        model.load_state_dict(state_dict)
    return model

# %% [markdown]
# ## Training

# %%
# model = retinanet_resnet50_fpn(pretrained=False,progress=False, num_classes=20)
model = torch.load('/content/gdrive/MyDrive/CElossRetinaNet34.pth')
model=model.to(dev)

optimizer= torch.optim.Adam(model.parameters(),lr=0.000006)
num_epochs=20

# %%
print_freq=10

for i in range(num_epochs):
  j=0
  for images, targets in train_loader:
    j=j+train_loader.batch_size
    images = list(image.to(dev) for image in images)
    targets = [{k: v.to(dev) for k, v in t.items()} for t in targets]
    model=model.train()
    out= model(images,targets)
    l1, l2=out['classification'],out['bbox_regression']
    loss=l1+l2
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if j%print_freq==0:
      print("Epoch: %d, Progress: %d/%d, Loss: %f, loss_classifier: %f, loss_box_reg: %f" % (i, j,len(train_loader.dataset),float(loss),float(l1),float(l2)))
  #train_one_epoch(model, optimizer, train_loader, dev, i, print_freq=20)

  # evaluate(model,test_loader,dev)
  torch.save(model, '/content/gdrive/MyDrive/CElossRetinaNet'+str(i+35)+'.pth')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch: 0, Progress: 10/2501, Loss: 0.835976, loss_classifier: 0.643911, loss_box_reg: 0.192064
# Epoch: 0, Progress: 20/2501, Loss: 1.244201, loss_classifier: 0.932386, loss_box_reg: 0.311816
# Epoch: 0, Progress: 30/2501, Loss: 1.366759, loss_classifier: 1.168094, loss_box_reg: 0.198665
# Epoch: 0, Progress: 40/2501, Loss: 1.293000, loss_classifier: 0.997328, loss_box_reg: 0.295673
# Epoch: 0, Progress: 50/2501, Loss: 0.756479, loss_classifier: 0.542448, loss_box_reg: 0.214031
# Epoch: 0, Progress: 60/2501, Loss: 0.528510, loss_classifier: 0.363212, loss_box_reg: 0.165298
# Epoch: 0, Progress: 70/2501, Loss: 1.391004, loss_classifier: 1.087562, loss_box_reg: 0.303442
# Epoch: 0, Progress: 80/2501, Loss: 1.024321, loss_classifier: 0.810606, loss_box_reg: 0.213715
# Epoch: 0, Progress: 90/2501, Loss: 0.319532, loss_classifier: 0.203105, loss_box_reg: 0.116427
# Epoch: 0, Progress: 100/2501, Loss: 1.815470, loss_classifier: 1.499226, loss_box_reg: 0.316244
# Epoch: 0, Progress: 110/2501, Loss: 0.324795, loss_classifier: 0.177963, loss_box_reg: 0.146833
# Epoch: 0, Progress: 120/2501, Loss: 0.339990, loss_classifier: 0.174725, loss_box_reg: 0.165265
# Epoch: 0, Progress: 130/2501, Loss: 0.216500, loss_classifier: 0.079175, loss_box_reg: 0.137325
# Epoch: 0, Progress: 140/2501, Loss: 0.628915, loss_classifier: 0.474571, loss_box_reg: 0.154344
# Epoch: 0, Progress: 150/2501, Loss: 1.027392, loss_classifier: 0.828736, loss_box_reg: 0.198656
# Epoch: 0, Progress: 160/2501, Loss: 1.690530, loss_classifier: 1.405123, loss_box_reg: 0.285407
# Epoch: 0, Progress: 170/2501, Loss: 1.358664, loss_classifier: 1.105015, loss_box_reg: 0.253649
# Epoch: 0, Progress: 180/2501, Loss: 0.404713, loss_classifier: 0.267226, loss_box_reg: 0.137487
# Epoch: 0, Progress: 190/2501, Loss: 1.857742, loss_classifier: 1.514492, loss_box_reg: 0.343250
# Epoch: 0, Progress: 200/2501, Loss: 1.180605, loss_classifier: 0.876691, loss_box_reg: 0.303914
# Epoch: 0, Progress: 210/2501, Loss: 0.579411, loss_classifier: 0.409755, loss_box_reg: 0.169656
# Epoch: 0, Progress: 220/2501, Loss: 1.116036, loss_classifier: 0.826768, loss_box_reg: 0.289268
# Epoch: 0, Progress: 230/2501, Loss: 0.917499, loss_classifier: 0.669354, loss_box_reg: 0.248145
# Epoch: 0, Progress: 240/2501, Loss: 0.623662, loss_classifier: 0.470559, loss_box_reg: 0.153103
# Epoch: 0, Progress: 250/2501, Loss: 1.503185, loss_classifier: 1.243232, loss_box_reg: 0.259953
# Epoch: 0, Progress: 260/2501, Loss: 1.398650, loss_classifier: 1.165612, loss_box_reg: 0.233038
# Epoch: 0, Progress: 270/2501, Loss: 1.025816, loss_classifier: 0.828893, loss_box_reg: 0.196923
# Epoch: 0, Progress: 280/2501, Loss: 1.088723, loss_classifier: 0.805994, loss_box_reg: 0.282729
# Epoch: 0, Progress: 290/2501, Loss: 0.336244, loss_classifier: 0.224776, loss_box_reg: 0.111468
# Epoch: 0, Progress: 300/2501, Loss: 0.509711, loss_classifier: 0.344512, loss_box_reg: 0.165199
# Epoch: 0, Progress: 310/2501, Loss: 0.483122, loss_classifier: 0.346718, loss_box_reg: 0.136405
# Epoch: 0, Progress: 320/2501, Loss: 1.354761, loss_classifier: 1.117517, loss_box_reg: 0.237243
# Epoch: 0, Progress: 330/2501, Loss: 1.722063, loss_classifier: 1.396444, loss_box_reg: 0.325619
# Epoch: 0, Progress: 340/2501, Loss: 0.993013, loss_classifier: 0.779774, loss_box_reg: 0.213238
# Epoch: 0, Progress: 350/2501, Loss: 0.552162, loss_classifier: 0.390179, loss_box_reg: 0.161983
# Epoch: 0, Progress: 360/2501, Loss: 1.404700, loss_classifier: 1.125235, loss_box_reg: 0.279466
# Epoch: 0, Progress: 370/2501, Loss: 1.118138, loss_classifier: 0.899127, loss_box_reg: 0.219011
# Epoch: 0, Progress: 380/2501, Loss: 0.761244, loss_classifier: 0.549318, loss_box_reg: 0.211926
# Epoch: 0, Progress: 390/2501, Loss: 0.497655, loss_classifier: 0.379370, loss_box_reg: 0.118286
# Epoch: 0, Progress: 400/2501, Loss: 1.912523, loss_classifier: 1.569611, loss_box_reg: 0.342912
# Epoch: 0, Progress: 410/2501, Loss: 1.482450, loss_classifier: 1.159101, loss_box_reg: 0.323350
# Epoch: 0, Progress: 420/2501, Loss: 1.792085, loss_classifier: 1.512027, loss_box_reg: 0.280059
# Epoch: 0, Progress: 430/2501, Loss: 1.399172, loss_classifier: 1.164773, loss_box_reg: 0.234399
# Epoch: 0, Progress: 440/2501, Loss: 0.578991, loss_classifier: 0.431924, loss_box_reg: 0.147066
# Epoch: 0, Progress: 450/2501, Loss: 1.828439, loss_classifier: 1.583127, loss_box_reg: 0.245312
# Epoch: 0, Progress: 460/2501, Loss: 1.970216, loss_classifier: 1.693294, loss_box_reg: 0.276922
# Epoch: 0, Progress: 470/2501, Loss: 0.716134, loss_classifier: 0.524680, loss_box_reg: 0.191454
# Epoch: 0, Progress: 480/2501, Loss: 0.938452, loss_classifier: 0.719411, loss_box_reg: 0.219041
# Epoch: 0, Progress: 490/2501, Loss: 1.602514, loss_classifier: 1.286919, loss_box_reg: 0.315594
# Epoch: 0, Progress: 500/2501, Loss: 0.491378, loss_classifier: 0.351234, loss_box_reg: 0.140144
# Epoch: 0, Progress: 510/2501, Loss: 0.390852, loss_classifier: 0.280246, loss_box_reg: 0.110606
# Epoch: 0, Progress: 520/2501, Loss: 0.579306, loss_classifier: 0.424835, loss_box_reg: 0.154471
# Epoch: 0, Progress: 530/2501, Loss: 1.341136, loss_classifier: 1.084901, loss_box_reg: 0.256234
# Epoch: 0, Progress: 540/2501, Loss: 0.532293, loss_classifier: 0.380871, loss_box_reg: 0.151422
# Epoch: 0, Progress: 550/2501, Loss: 1.249185, loss_classifier: 1.022171, loss_box_reg: 0.227014
# Epoch: 0, Progress: 560/2501, Loss: 1.762625, loss_classifier: 1.510918, loss_box_reg: 0.251707
# Epoch: 0, Progress: 570/2501, Loss: 0.864202, loss_classifier: 0.615732, loss_box_reg: 0.248471
# Epoch: 0, Progress: 580/2501, Loss: 1.546090, loss_classifier: 1.181638, loss_box_reg: 0.364453
# Epoch: 0, Progress: 590/2501, Loss: 3.471458, loss_classifier: 3.137269, loss_box_reg: 0.334189
# Epoch: 0, Progress: 600/2501, Loss: 1.139633, loss_classifier: 0.881792, loss_box_reg: 0.257841
# Epoch: 0, Progress: 610/2501, Loss: 0.632441, loss_classifier: 0.460225, loss_box_reg: 0.172216
# Epoch: 0, Progress: 620/2501, Loss: 0.698494, loss_classifier: 0.468187, loss_box_reg: 0.230308
# Epoch: 0, Progress: 630/2501, Loss: 2.013807, loss_classifier: 1.714777, loss_box_reg: 0.299030
# Epoch: 0, Progress: 640/2501, Loss: 0.940344, loss_classifier: 0.662186, loss_box_reg: 0.278158
# Epoch: 0, Progress: 650/2501, Loss: 1.092843, loss_classifier: 0.805980, loss_box_reg: 0.286863
# Epoch: 0, Progress: 660/2501, Loss: 0.988903, loss_classifier: 0.788619, loss_box_reg: 0.200284
# Epoch: 0, Progress: 670/2501, Loss: 0.908015, loss_classifier: 0.673715, loss_box_reg: 0.234300
# Epoch: 0, Progress: 680/2501, Loss: 0.416971, loss_classifier: 0.301690, loss_box_reg: 0.115280
# Epoch: 0, Progress: 690/2501, Loss: 2.620074, loss_classifier: 2.181957, loss_box_reg: 0.438117
# Epoch: 0, Progress: 700/2501, Loss: 1.640432, loss_classifier: 1.353031, loss_box_reg: 0.287401
# Epoch: 0, Progress: 710/2501, Loss: 1.199620, loss_classifier: 0.974241, loss_box_reg: 0.225379
# Epoch: 0, Progress: 720/2501, Loss: 1.840734, loss_classifier: 1.527930, loss_box_reg: 0.312805
# Epoch: 0, Progress: 730/2501, Loss: 2.071240, loss_classifier: 1.823558, loss_box_reg: 0.247682
# Epoch: 0, Progress: 740/2501, Loss: 1.412811, loss_classifier: 1.166527, loss_box_reg: 0.246284
# Epoch: 0, Progress: 750/2501, Loss: 0.864286, loss_classifier: 0.658540, loss_box_reg: 0.205746
# Epoch: 0, Progress: 760/2501, Loss: 2.858907, loss_classifier: 2.541672, loss_box_reg: 0.317235
# Epoch: 0, Progress: 770/2501, Loss: 1.139670, loss_classifier: 0.894201, loss_box_reg: 0.245470
# Epoch: 0, Progress: 780/2501, Loss: 1.462447, loss_classifier: 1.160351, loss_box_reg: 0.302096
# Epoch: 0, Progress: 790/2501, Loss: 1.195401, loss_classifier: 0.957358, loss_box_reg: 0.238043
# Epoch: 0, Progress: 800/2501, Loss: 1.074837, loss_classifier: 0.850420, loss_box_reg: 0.224417
# Epoch: 0, Progress: 810/2501, Loss: 0.787670, loss_classifier: 0.568113, loss_box_reg: 0.219557
# Epoch: 0, Progress: 820/2501, Loss: 0.859858, loss_classifier: 0.641208, loss_box_reg: 0.218649
# Epoch: 0, Progress: 830/2501, Loss: 1.198625, loss_classifier: 0.915585, loss_box_reg: 0.283040
# Epoch: 0, Progress: 840/2501, Loss: 1.834469, loss_classifier: 1.505115, loss_box_reg: 0.329355
# Epoch: 0, Progress: 850/2501, Loss: 1.367866, loss_classifier: 1.110908, loss_box_reg: 0.256958
# Epoch: 0, Progress: 860/2501, Loss: 0.844321, loss_classifier: 0.633432, loss_box_reg: 0.210889
# Epoch: 0, Progress: 870/2501, Loss: 0.817035, loss_classifier: 0.548687, loss_box_reg: 0.268348
# Epoch: 0, Progress: 880/2501, Loss: 1.124728, loss_classifier: 0.918876, loss_box_reg: 0.205852
# Epoch: 0, Progress: 890/2501, Loss: 2.083731, loss_classifier: 1.778838, loss_box_reg: 0.304893
# Epoch: 0, Progress: 900/2501, Loss: 1.165575, loss_classifier: 0.889758, loss_box_reg: 0.275817
# Epoch: 0, Progress: 910/2501, Loss: 0.984519, loss_classifier: 0.688041, loss_box_reg: 0.296477
# Epoch: 0, Progress: 920/2501, Loss: 1.682289, loss_classifier: 1.401736, loss_box_reg: 0.280554
# Epoch: 0, Progress: 930/2501, Loss: 0.907967, loss_classifier: 0.655181, loss_box_reg: 0.252786
# Epoch: 0, Progress: 940/2501, Loss: 1.230703, loss_classifier: 1.005150, loss_box_reg: 0.225553
# Epoch: 0, Progress: 950/2501, Loss: 1.606174, loss_classifier: 1.272652, loss_box_reg: 0.333522
# Epoch: 0, Progress: 960/2501, Loss: 0.586739, loss_classifier: 0.398641, loss_box_reg: 0.188098
# Epoch: 0, Progress: 970/2501, Loss: 0.387834, loss_classifier: 0.222462, loss_box_reg: 0.165372
# Epoch: 0, Progress: 980/2501, Loss: 0.609719, loss_classifier: 0.471393, loss_box_reg: 0.138326
# Epoch: 0, Progress: 990/2501, Loss: 1.559844, loss_classifier: 1.272269, loss_box_reg: 0.287575
# Epoch: 0, Progress: 1000/2501, Loss: 0.616570, loss_classifier: 0.400612, loss_box_reg: 0.215958
# Epoch: 0, Progress: 1010/2501, Loss: 0.357477, loss_classifier: 0.222916, loss_box_reg: 0.134561
# Epoch: 0, Progress: 1020/2501, Loss: 1.016140, loss_classifier: 0.804234, loss_box_reg: 0.211905
# Epoch: 0, Progress: 1030/2501, Loss: 0.726152, loss_classifier: 0.487854, loss_box_reg: 0.238298
# Epoch: 0, Progress: 1040/2501, Loss: 1.066430, loss_classifier: 0.809726, loss_box_reg: 0.256704
# Epoch: 0, Progress: 1050/2501, Loss: 0.325628, loss_classifier: 0.169837, loss_box_reg: 0.155792
# Epoch: 0, Progress: 1060/2501, Loss: 0.571032, loss_classifier: 0.394677, loss_box_reg: 0.176355
# Epoch: 0, Progress: 1070/2501, Loss: 0.513552, loss_classifier: 0.362847, loss_box_reg: 0.150705
# Epoch: 0, Progress: 1080/2501, Loss: 0.832859, loss_classifier: 0.673147, loss_box_reg: 0.159712
# Epoch: 0, Progress: 1090/2501, Loss: 1.919839, loss_classifier: 1.661035, loss_box_reg: 0.258803
# Epoch: 0, Progress: 1100/2501, Loss: 1.016046, loss_classifier: 0.880095, loss_box_reg: 0.135951
# Epoch: 0, Progress: 1110/2501, Loss: 0.580409, loss_classifier: 0.406648, loss_box_reg: 0.173761
# Epoch: 0, Progress: 1120/2501, Loss: 1.401572, loss_classifier: 1.165929, loss_box_reg: 0.235643
# Epoch: 0, Progress: 1130/2501, Loss: 0.741055, loss_classifier: 0.539019, loss_box_reg: 0.202036
# Epoch: 0, Progress: 1140/2501, Loss: 1.072723, loss_classifier: 0.797929, loss_box_reg: 0.274794
# Epoch: 0, Progress: 1150/2501, Loss: 1.268926, loss_classifier: 1.064122, loss_box_reg: 0.204804
# Epoch: 0, Progress: 1160/2501, Loss: 0.466905, loss_classifier: 0.342533, loss_box_reg: 0.124371
# Epoch: 0, Progress: 1170/2501, Loss: 0.599309, loss_classifier: 0.444878, loss_box_reg: 0.154432
# Epoch: 0, Progress: 1180/2501, Loss: 1.405323, loss_classifier: 1.071273, loss_box_reg: 0.334049
# Epoch: 0, Progress: 1190/2501, Loss: 1.733246, loss_classifier: 1.300000, loss_box_reg: 0.433246
# Epoch: 0, Progress: 1200/2501, Loss: 0.999000, loss_classifier: 0.815509, loss_box_reg: 0.183492
# Epoch: 0, Progress: 1210/2501, Loss: 0.386042, loss_classifier: 0.267213, loss_box_reg: 0.118829
# Epoch: 0, Progress: 1220/2501, Loss: 0.437316, loss_classifier: 0.307097, loss_box_reg: 0.130219
# Epoch: 0, Progress: 1230/2501, Loss: 1.564101, loss_classifier: 1.227958, loss_box_reg: 0.336144
# Epoch: 0, Progress: 1240/2501, Loss: 0.451834, loss_classifier: 0.312017, loss_box_reg: 0.139818
# Epoch: 0, Progress: 1250/2501, Loss: 1.397954, loss_classifier: 1.164374, loss_box_reg: 0.233580
# Epoch: 0, Progress: 1260/2501, Loss: 1.514428, loss_classifier: 1.181001, loss_box_reg: 0.333427
# Epoch: 0, Progress: 1270/2501, Loss: 0.955580, loss_classifier: 0.713090, loss_box_reg: 0.242490
# Epoch: 0, Progress: 1280/2501, Loss: 0.816831, loss_classifier: 0.588915, loss_box_reg: 0.227916
# Epoch: 0, Progress: 1290/2501, Loss: 1.077732, loss_classifier: 0.882947, loss_box_reg: 0.194785
# Epoch: 0, Progress: 1300/2501, Loss: 0.436238, loss_classifier: 0.230873, loss_box_reg: 0.205365
# Epoch: 0, Progress: 1310/2501, Loss: 1.198235, loss_classifier: 0.982369, loss_box_reg: 0.215866
# Epoch: 0, Progress: 1320/2501, Loss: 1.220184, loss_classifier: 0.950658, loss_box_reg: 0.269527
# Epoch: 0, Progress: 1330/2501, Loss: 2.345387, loss_classifier: 2.046395, loss_box_reg: 0.298992
# Epoch: 0, Progress: 1340/2501, Loss: 1.465410, loss_classifier: 1.175489, loss_box_reg: 0.289920
# Epoch: 0, Progress: 1350/2501, Loss: 0.559632, loss_classifier: 0.390207, loss_box_reg: 0.169425
# Epoch: 0, Progress: 1360/2501, Loss: 0.860401, loss_classifier: 0.632750, loss_box_reg: 0.227652
# Epoch: 0, Progress: 1370/2501, Loss: 0.805890, loss_classifier: 0.570532, loss_box_reg: 0.235358
# Epoch: 0, Progress: 1380/2501, Loss: 0.731578, loss_classifier: 0.540519, loss_box_reg: 0.191059
# Epoch: 0, Progress: 1390/2501, Loss: 0.389774, loss_classifier: 0.239086, loss_box_reg: 0.150688
# Epoch: 0, Progress: 1400/2501, Loss: 1.615470, loss_classifier: 1.340550, loss_box_reg: 0.274920
# Epoch: 0, Progress: 1410/2501, Loss: 0.664794, loss_classifier: 0.491357, loss_box_reg: 0.173437
# Epoch: 0, Progress: 1420/2501, Loss: 0.746487, loss_classifier: 0.542727, loss_box_reg: 0.203761
# Epoch: 0, Progress: 1430/2501, Loss: 1.016788, loss_classifier: 0.778681, loss_box_reg: 0.238107
# Epoch: 0, Progress: 1440/2501, Loss: 1.575268, loss_classifier: 1.244658, loss_box_reg: 0.330610
# Epoch: 0, Progress: 1450/2501, Loss: 1.757829, loss_classifier: 1.397149, loss_box_reg: 0.360680
# Epoch: 0, Progress: 1460/2501, Loss: 1.317647, loss_classifier: 0.977634, loss_box_reg: 0.340014
# Epoch: 0, Progress: 1470/2501, Loss: 1.024831, loss_classifier: 0.811564, loss_box_reg: 0.213267
# Epoch: 0, Progress: 1480/2501, Loss: 0.400226, loss_classifier: 0.240197, loss_box_reg: 0.160029
# Epoch: 0, Progress: 1490/2501, Loss: 1.126909, loss_classifier: 0.895650, loss_box_reg: 0.231260
# Epoch: 0, Progress: 1500/2501, Loss: 0.980383, loss_classifier: 0.724000, loss_box_reg: 0.256384
# Epoch: 0, Progress: 1510/2501, Loss: 0.243114, loss_classifier: 0.121907, loss_box_reg: 0.121207
# Epoch: 0, Progress: 1520/2501, Loss: 0.930348, loss_classifier: 0.645002, loss_box_reg: 0.285346
# Epoch: 0, Progress: 1530/2501, Loss: 0.978644, loss_classifier: 0.673905, loss_box_reg: 0.304738
# Epoch: 0, Progress: 1540/2501, Loss: 0.453420, loss_classifier: 0.317998, loss_box_reg: 0.135422
# Epoch: 0, Progress: 1550/2501, Loss: 0.896472, loss_classifier: 0.687939, loss_box_reg: 0.208533
# Epoch: 0, Progress: 1560/2501, Loss: 1.142490, loss_classifier: 0.801554, loss_box_reg: 0.340936
# Epoch: 0, Progress: 1570/2501, Loss: 1.219402, loss_classifier: 1.064951, loss_box_reg: 0.154451
# Epoch: 0, Progress: 1580/2501, Loss: 1.275776, loss_classifier: 1.060402, loss_box_reg: 0.215374
# Epoch: 0, Progress: 1590/2501, Loss: 0.467121, loss_classifier: 0.290378, loss_box_reg: 0.176743
# Epoch: 0, Progress: 1600/2501, Loss: 0.564289, loss_classifier: 0.393939, loss_box_reg: 0.170350
# Epoch: 0, Progress: 1610/2501, Loss: 1.015271, loss_classifier: 0.806340, loss_box_reg: 0.208930
# Epoch: 0, Progress: 1620/2501, Loss: 1.737274, loss_classifier: 1.418064, loss_box_reg: 0.319210
# Epoch: 0, Progress: 1630/2501, Loss: 1.221364, loss_classifier: 0.990009, loss_box_reg: 0.231356
# Epoch: 0, Progress: 1640/2501, Loss: 0.351114, loss_classifier: 0.225398, loss_box_reg: 0.125717
# Epoch: 0, Progress: 1650/2501, Loss: 1.129892, loss_classifier: 0.866087, loss_box_reg: 0.263804
# Epoch: 0, Progress: 1660/2501, Loss: 1.422599, loss_classifier: 1.144349, loss_box_reg: 0.278251
# Epoch: 0, Progress: 1670/2501, Loss: 1.049347, loss_classifier: 0.763778, loss_box_reg: 0.285569
# Epoch: 0, Progress: 1680/2501, Loss: 0.245194, loss_classifier: 0.128173, loss_box_reg: 0.117021
# Epoch: 0, Progress: 1690/2501, Loss: 0.682793, loss_classifier: 0.497359, loss_box_reg: 0.185434
# Epoch: 0, Progress: 1700/2501, Loss: 1.106686, loss_classifier: 0.848446, loss_box_reg: 0.258241
# Epoch: 0, Progress: 1710/2501, Loss: 0.952976, loss_classifier: 0.805099, loss_box_reg: 0.147877
# Epoch: 0, Progress: 1720/2501, Loss: 1.731569, loss_classifier: 1.418722, loss_box_reg: 0.312847
# Epoch: 0, Progress: 1730/2501, Loss: 0.870873, loss_classifier: 0.650061, loss_box_reg: 0.220812
# Epoch: 0, Progress: 1740/2501, Loss: 0.943476, loss_classifier: 0.674919, loss_box_reg: 0.268558
# Epoch: 0, Progress: 1750/2501, Loss: 1.201349, loss_classifier: 0.876017, loss_box_reg: 0.325332
# Epoch: 0, Progress: 1760/2501, Loss: 1.197737, loss_classifier: 0.903390, loss_box_reg: 0.294347
# Epoch: 0, Progress: 1770/2501, Loss: 0.722255, loss_classifier: 0.525332, loss_box_reg: 0.196923
# Epoch: 0, Progress: 1780/2501, Loss: 2.584933, loss_classifier: 2.208463, loss_box_reg: 0.376471
# Epoch: 0, Progress: 1790/2501, Loss: 2.057888, loss_classifier: 1.752096, loss_box_reg: 0.305791
# Epoch: 0, Progress: 1800/2501, Loss: 1.223257, loss_classifier: 0.906348, loss_box_reg: 0.316909
# Epoch: 0, Progress: 1810/2501, Loss: 0.339601, loss_classifier: 0.199914, loss_box_reg: 0.139687
# Epoch: 0, Progress: 1820/2501, Loss: 1.397302, loss_classifier: 1.137603, loss_box_reg: 0.259699
# Epoch: 0, Progress: 1830/2501, Loss: 0.226422, loss_classifier: 0.103693, loss_box_reg: 0.122729
# Epoch: 0, Progress: 1840/2501, Loss: 1.426024, loss_classifier: 1.163636, loss_box_reg: 0.262388
# Epoch: 0, Progress: 1850/2501, Loss: 0.736181, loss_classifier: 0.460291, loss_box_reg: 0.275890
# Epoch: 0, Progress: 1860/2501, Loss: 1.085787, loss_classifier: 0.843770, loss_box_reg: 0.242017
# Epoch: 0, Progress: 1870/2501, Loss: 0.897901, loss_classifier: 0.677026, loss_box_reg: 0.220875
# Epoch: 0, Progress: 1880/2501, Loss: 1.002021, loss_classifier: 0.768186, loss_box_reg: 0.233835
# Epoch: 0, Progress: 1890/2501, Loss: 1.741117, loss_classifier: 1.451698, loss_box_reg: 0.289418
# Epoch: 0, Progress: 1900/2501, Loss: 1.627862, loss_classifier: 1.382003, loss_box_reg: 0.245859
# Epoch: 0, Progress: 1910/2501, Loss: 0.590060, loss_classifier: 0.406333, loss_box_reg: 0.183728
# Epoch: 0, Progress: 1920/2501, Loss: 1.838701, loss_classifier: 1.476910, loss_box_reg: 0.361791
# Epoch: 0, Progress: 1930/2501, Loss: 0.855536, loss_classifier: 0.642711, loss_box_reg: 0.212825
# Epoch: 0, Progress: 1940/2501, Loss: 1.928295, loss_classifier: 1.638329, loss_box_reg: 0.289966
# Epoch: 0, Progress: 1950/2501, Loss: 0.686983, loss_classifier: 0.510468, loss_box_reg: 0.176516
# Epoch: 0, Progress: 1960/2501, Loss: 1.007786, loss_classifier: 0.781244, loss_box_reg: 0.226542
# Epoch: 0, Progress: 1970/2501, Loss: 3.033553, loss_classifier: 2.653514, loss_box_reg: 0.380039
# Epoch: 0, Progress: 1980/2501, Loss: 2.606998, loss_classifier: 2.300484, loss_box_reg: 0.306514
# Epoch: 0, Progress: 1990/2501, Loss: 2.574184, loss_classifier: 2.220051, loss_box_reg: 0.354133
# Epoch: 0, Progress: 2000/2501, Loss: 1.541719, loss_classifier: 1.265313, loss_box_reg: 0.276407
# Epoch: 0, Progress: 2010/2501, Loss: 0.803310, loss_classifier: 0.618851, loss_box_reg: 0.184459
# Epoch: 0, Progress: 2020/2501, Loss: 0.932543, loss_classifier: 0.735530, loss_box_reg: 0.197013
# Epoch: 0, Progress: 2030/2501, Loss: 1.534997, loss_classifier: 1.265264, loss_box_reg: 0.269733
# Epoch: 0, Progress: 2040/2501, Loss: 0.851979, loss_classifier: 0.646725, loss_box_reg: 0.205254
# Epoch: 0, Progress: 2050/2501, Loss: 1.103194, loss_classifier: 0.857362, loss_box_reg: 0.245832
# Epoch: 0, Progress: 2060/2501, Loss: 0.474241, loss_classifier: 0.310317, loss_box_reg: 0.163923
# Epoch: 0, Progress: 2070/2501, Loss: 0.871020, loss_classifier: 0.667247, loss_box_reg: 0.203773
# Epoch: 0, Progress: 2080/2501, Loss: 0.801101, loss_classifier: 0.581126, loss_box_reg: 0.219975
# Epoch: 0, Progress: 2090/2501, Loss: 0.495763, loss_classifier: 0.294553, loss_box_reg: 0.201211
# Epoch: 0, Progress: 2100/2501, Loss: 0.329112, loss_classifier: 0.190321, loss_box_reg: 0.138791
# Epoch: 0, Progress: 2110/2501, Loss: 0.765706, loss_classifier: 0.577108, loss_box_reg: 0.188597
# Epoch: 0, Progress: 2120/2501, Loss: 1.644623, loss_classifier: 1.344640, loss_box_reg: 0.299983
# Epoch: 0, Progress: 2130/2501, Loss: 1.195315, loss_classifier: 0.958182, loss_box_reg: 0.237134
# Epoch: 0, Progress: 2140/2501, Loss: 0.409863, loss_classifier: 0.263735, loss_box_reg: 0.146127
# Epoch: 0, Progress: 2150/2501, Loss: 1.485490, loss_classifier: 1.225334, loss_box_reg: 0.260157
# Epoch: 0, Progress: 2160/2501, Loss: 1.053939, loss_classifier: 0.778332, loss_box_reg: 0.275606
# Epoch: 0, Progress: 2170/2501, Loss: 1.516965, loss_classifier: 1.211867, loss_box_reg: 0.305099
# Epoch: 0, Progress: 2180/2501, Loss: 0.714054, loss_classifier: 0.486619, loss_box_reg: 0.227434
# Epoch: 0, Progress: 2190/2501, Loss: 0.519306, loss_classifier: 0.335580, loss_box_reg: 0.183725
# Epoch: 0, Progress: 2200/2501, Loss: 1.965750, loss_classifier: 1.576455, loss_box_reg: 0.389295
# Epoch: 0, Progress: 2210/2501, Loss: 0.817501, loss_classifier: 0.623401, loss_box_reg: 0.194100
# Epoch: 0, Progress: 2220/2501, Loss: 1.536893, loss_classifier: 1.219003, loss_box_reg: 0.317890
# Epoch: 0, Progress: 2230/2501, Loss: 1.242939, loss_classifier: 0.946863, loss_box_reg: 0.296076
# Epoch: 0, Progress: 2240/2501, Loss: 1.878461, loss_classifier: 1.638274, loss_box_reg: 0.240187
# Epoch: 0, Progress: 2250/2501, Loss: 1.407362, loss_classifier: 1.159019, loss_box_reg: 0.248343
# Epoch: 0, Progress: 2260/2501, Loss: 0.792567, loss_classifier: 0.604054, loss_box_reg: 0.188513
# Epoch: 0, Progress: 2270/2501, Loss: 0.765143, loss_classifier: 0.575285, loss_box_reg: 0.189858
# Epoch: 0, Progress: 2280/2501, Loss: 0.902777, loss_classifier: 0.653826, loss_box_reg: 0.248951
# Epoch: 0, Progress: 2290/2501, Loss: 0.371189, loss_classifier: 0.223695, loss_box_reg: 0.147495
# Epoch: 0, Progress: 2300/2501, Loss: 0.707371, loss_classifier: 0.514700, loss_box_reg: 0.192671
# Epoch: 0, Progress: 2310/2501, Loss: 0.677092, loss_classifier: 0.456373, loss_box_reg: 0.220719
# Epoch: 0, Progress: 2320/2501, Loss: 1.068874, loss_classifier: 0.876046, loss_box_reg: 0.192829
# Epoch: 0, Progress: 2330/2501, Loss: 1.069416, loss_classifier: 0.877938, loss_box_reg: 0.191478
# Epoch: 0, Progress: 2340/2501, Loss: 1.110171, loss_classifier: 0.864961, loss_box_reg: 0.245211
# Epoch: 0, Progress: 2350/2501, Loss: 0.661199, loss_classifier: 0.530542, loss_box_reg: 0.130657
# Epoch: 0, Progress: 2360/2501, Loss: 1.496156, loss_classifier: 1.226457, loss_box_reg: 0.269700
# Epoch: 0, Progress: 2370/2501, Loss: 1.262271, loss_classifier: 1.032927, loss_box_reg: 0.229344
# Epoch: 0, Progress: 2380/2501, Loss: 2.022463, loss_classifier: 1.696209, loss_box_reg: 0.326254
# Epoch: 0, Progress: 2390/2501, Loss: 0.795057, loss_classifier: 0.606608, loss_box_reg: 0.188449
# Epoch: 0, Progress: 2400/2501, Loss: 1.686726, loss_classifier: 1.363009, loss_box_reg: 0.323716
# Epoch: 0, Progress: 2410/2501, Loss: 0.813127, loss_classifier: 0.576262, loss_box_reg: 0.236865
# Epoch: 0, Progress: 2420/2501, Loss: 1.731247, loss_classifier: 1.392343, loss_box_reg: 0.338904
# Epoch: 0, Progress: 2430/2501, Loss: 0.939775, loss_classifier: 0.686808, loss_box_reg: 0.252966
# Epoch: 0, Progress: 2440/2501, Loss: 1.330798, loss_classifier: 1.062624, loss_box_reg: 0.268174
# Epoch: 0, Progress: 2450/2501, Loss: 3.177199, loss_classifier: 2.813686, loss_box_reg: 0.363513
# Epoch: 0, Progress: 2460/2501, Loss: 1.541028, loss_classifier: 1.372270, loss_box_reg: 0.168758
# Epoch: 0, Progress: 2470/2501, Loss: 2.078803, loss_classifier: 1.772820, loss_box_reg: 0.305983
# Epoch: 0, Progress: 2480/2501, Loss: 1.157857, loss_classifier: 0.920109, loss_box_reg: 0.237748
# Epoch: 0, Progress: 2490/2501, Loss: 1.904905, loss_classifier: 1.598460, loss_box_reg: 0.306445
# Epoch: 0, Progress: 2500/2501, Loss: 1.856596, loss_classifier: 1.605672, loss_box_reg: 0.250925
# Epoch: 1, Progress: 10/2501, Loss: 1.276712, loss_classifier: 1.069894, loss_box_reg: 0.206819
# Epoch: 1, Progress: 20/2501, Loss: 0.666307, loss_classifier: 0.545227, loss_box_reg: 0.121080
# Epoch: 1, Progress: 30/2501, Loss: 0.392768, loss_classifier: 0.254005, loss_box_reg: 0.138763
# Epoch: 1, Progress: 40/2501, Loss: 0.974203, loss_classifier: 0.799714, loss_box_reg: 0.174489
# Epoch: 1, Progress: 50/2501, Loss: 1.069853, loss_classifier: 0.848209, loss_box_reg: 0.221644
# Epoch: 1, Progress: 60/2501, Loss: 1.253222, loss_classifier: 1.040494, loss_box_reg: 0.212728
# Epoch: 1, Progress: 70/2501, Loss: 0.484057, loss_classifier: 0.277513, loss_box_reg: 0.206544
# Epoch: 1, Progress: 80/2501, Loss: 0.515656, loss_classifier: 0.376072, loss_box_reg: 0.139584
# Epoch: 1, Progress: 90/2501, Loss: 0.856209, loss_classifier: 0.657701, loss_box_reg: 0.198508
# Epoch: 1, Progress: 100/2501, Loss: 0.550932, loss_classifier: 0.360881, loss_box_reg: 0.190051
# Epoch: 1, Progress: 110/2501, Loss: 1.577192, loss_classifier: 1.330949, loss_box_reg: 0.246243
# Epoch: 1, Progress: 120/2501, Loss: 2.172584, loss_classifier: 1.832377, loss_box_reg: 0.340207
# Epoch: 1, Progress: 130/2501, Loss: 0.764828, loss_classifier: 0.548046, loss_box_reg: 0.216782
# Epoch: 1, Progress: 140/2501, Loss: 1.617593, loss_classifier: 1.344356, loss_box_reg: 0.273238
# Epoch: 1, Progress: 150/2501, Loss: 2.659336, loss_classifier: 2.242560, loss_box_reg: 0.416776
# Epoch: 1, Progress: 160/2501, Loss: 1.702536, loss_classifier: 1.404467, loss_box_reg: 0.298070
# Epoch: 1, Progress: 170/2501, Loss: 0.429804, loss_classifier: 0.289930, loss_box_reg: 0.139874
# Epoch: 1, Progress: 180/2501, Loss: 0.722680, loss_classifier: 0.565462, loss_box_reg: 0.157218
# Epoch: 1, Progress: 190/2501, Loss: 1.373546, loss_classifier: 1.106985, loss_box_reg: 0.266561
# Epoch: 1, Progress: 200/2501, Loss: 2.244699, loss_classifier: 1.943348, loss_box_reg: 0.301351
# Epoch: 1, Progress: 210/2501, Loss: 1.464220, loss_classifier: 1.250761, loss_box_reg: 0.213459
# Epoch: 1, Progress: 220/2501, Loss: 0.429341, loss_classifier: 0.253516, loss_box_reg: 0.175824
# Epoch: 1, Progress: 230/2501, Loss: 1.612303, loss_classifier: 1.326022, loss_box_reg: 0.286281
# Epoch: 1, Progress: 240/2501, Loss: 1.173267, loss_classifier: 0.913623, loss_box_reg: 0.259644
# Epoch: 1, Progress: 250/2501, Loss: 1.027007, loss_classifier: 0.768333, loss_box_reg: 0.258674
# Epoch: 1, Progress: 260/2501, Loss: 0.881607, loss_classifier: 0.652448, loss_box_reg: 0.229159
# Epoch: 1, Progress: 270/2501, Loss: 0.269381, loss_classifier: 0.124691, loss_box_reg: 0.144690
# Epoch: 1, Progress: 280/2501, Loss: 0.613444, loss_classifier: 0.444842, loss_box_reg: 0.168602
# Epoch: 1, Progress: 290/2501, Loss: 0.415780, loss_classifier: 0.265432, loss_box_reg: 0.150348
# Epoch: 1, Progress: 300/2501, Loss: 1.464293, loss_classifier: 1.181926, loss_box_reg: 0.282367
# Epoch: 1, Progress: 310/2501, Loss: 0.409583, loss_classifier: 0.249501, loss_box_reg: 0.160083
# Epoch: 1, Progress: 320/2501, Loss: 0.772288, loss_classifier: 0.582493, loss_box_reg: 0.189794
# Epoch: 1, Progress: 330/2501, Loss: 0.707853, loss_classifier: 0.590505, loss_box_reg: 0.117347
# Epoch: 1, Progress: 340/2501, Loss: 1.122889, loss_classifier: 0.875378, loss_box_reg: 0.247510
# Epoch: 1, Progress: 350/2501, Loss: 0.684424, loss_classifier: 0.512735, loss_box_reg: 0.171689
# Epoch: 1, Progress: 360/2501, Loss: 0.916875, loss_classifier: 0.620957, loss_box_reg: 0.295918
# Epoch: 1, Progress: 370/2501, Loss: 1.388199, loss_classifier: 1.130423, loss_box_reg: 0.257775
# Epoch: 1, Progress: 380/2501, Loss: 0.798708, loss_classifier: 0.643523, loss_box_reg: 0.155185
# Epoch: 1, Progress: 390/2501, Loss: 1.376688, loss_classifier: 1.129516, loss_box_reg: 0.247172
# Epoch: 1, Progress: 400/2501, Loss: 0.523914, loss_classifier: 0.348328, loss_box_reg: 0.175586
# Epoch: 1, Progress: 410/2501, Loss: 1.793063, loss_classifier: 1.501246, loss_box_reg: 0.291817
# Epoch: 1, Progress: 420/2501, Loss: 1.886194, loss_classifier: 1.540828, loss_box_reg: 0.345366
# Epoch: 1, Progress: 430/2501, Loss: 0.819830, loss_classifier: 0.596864, loss_box_reg: 0.222966
# Epoch: 1, Progress: 440/2501, Loss: 0.509759, loss_classifier: 0.292141, loss_box_reg: 0.217618
# Epoch: 1, Progress: 450/2501, Loss: 0.765428, loss_classifier: 0.555036, loss_box_reg: 0.210392
# Epoch: 1, Progress: 460/2501, Loss: 1.339299, loss_classifier: 1.042958, loss_box_reg: 0.296341
# Epoch: 1, Progress: 470/2501, Loss: 0.949773, loss_classifier: 0.775091, loss_box_reg: 0.174682
# Epoch: 1, Progress: 480/2501, Loss: 1.754268, loss_classifier: 1.425801, loss_box_reg: 0.328466
# Epoch: 1, Progress: 490/2501, Loss: 0.985922, loss_classifier: 0.749618, loss_box_reg: 0.236303
# Epoch: 1, Progress: 500/2501, Loss: 0.730499, loss_classifier: 0.541561, loss_box_reg: 0.188938
# Epoch: 1, Progress: 510/2501, Loss: 1.374564, loss_classifier: 1.072905, loss_box_reg: 0.301659
# Epoch: 1, Progress: 520/2501, Loss: 1.349944, loss_classifier: 1.163659, loss_box_reg: 0.186285
# Epoch: 1, Progress: 530/2501, Loss: 1.710438, loss_classifier: 1.431090, loss_box_reg: 0.279349
# Epoch: 1, Progress: 540/2501, Loss: 0.534368, loss_classifier: 0.324129, loss_box_reg: 0.210239
# Epoch: 1, Progress: 550/2501, Loss: 0.736702, loss_classifier: 0.541733, loss_box_reg: 0.194969
# Epoch: 1, Progress: 560/2501, Loss: 1.489877, loss_classifier: 1.269699, loss_box_reg: 0.220179
# Epoch: 1, Progress: 570/2501, Loss: 0.933055, loss_classifier: 0.686088, loss_box_reg: 0.246967
# Epoch: 1, Progress: 580/2501, Loss: 1.051587, loss_classifier: 0.833154, loss_box_reg: 0.218434
# Epoch: 1, Progress: 590/2501, Loss: 1.374966, loss_classifier: 1.209889, loss_box_reg: 0.165077
# Epoch: 1, Progress: 600/2501, Loss: 0.673163, loss_classifier: 0.476820, loss_box_reg: 0.196343
# Epoch: 1, Progress: 610/2501, Loss: 1.787684, loss_classifier: 1.384967, loss_box_reg: 0.402717
# Epoch: 1, Progress: 620/2501, Loss: 0.874049, loss_classifier: 0.678372, loss_box_reg: 0.195677
# Epoch: 1, Progress: 630/2501, Loss: 3.249321, loss_classifier: 2.999002, loss_box_reg: 0.250319
# Epoch: 1, Progress: 640/2501, Loss: 0.800464, loss_classifier: 0.678531, loss_box_reg: 0.121933
# Epoch: 1, Progress: 650/2501, Loss: 1.170471, loss_classifier: 1.012928, loss_box_reg: 0.157543
# Epoch: 1, Progress: 660/2501, Loss: 1.129814, loss_classifier: 0.931608, loss_box_reg: 0.198206
# Epoch: 1, Progress: 670/2501, Loss: 2.156479, loss_classifier: 1.811769, loss_box_reg: 0.344710
# Epoch: 1, Progress: 680/2501, Loss: 1.194141, loss_classifier: 1.025346, loss_box_reg: 0.168794
# Epoch: 1, Progress: 690/2501, Loss: 2.229766, loss_classifier: 1.872746, loss_box_reg: 0.357019
# Epoch: 1, Progress: 700/2501, Loss: 1.371043, loss_classifier: 1.087175, loss_box_reg: 0.283869
# Epoch: 1, Progress: 710/2501, Loss: 0.987204, loss_classifier: 0.782849, loss_box_reg: 0.204354
# Epoch: 1, Progress: 720/2501, Loss: 0.918393, loss_classifier: 0.725608, loss_box_reg: 0.192785
# Epoch: 1, Progress: 730/2501, Loss: 1.905246, loss_classifier: 1.637746, loss_box_reg: 0.267501
# Epoch: 1, Progress: 740/2501, Loss: 0.970041, loss_classifier: 0.677699, loss_box_reg: 0.292342
# Epoch: 1, Progress: 750/2501, Loss: 1.192991, loss_classifier: 0.977306, loss_box_reg: 0.215685
# Epoch: 1, Progress: 760/2501, Loss: 2.142205, loss_classifier: 1.819231, loss_box_reg: 0.322974
# Epoch: 1, Progress: 770/2501, Loss: 1.508463, loss_classifier: 1.218544, loss_box_reg: 0.289919
# Epoch: 1, Progress: 780/2501, Loss: 1.543321, loss_classifier: 1.330457, loss_box_reg: 0.212864
# Epoch: 1, Progress: 790/2501, Loss: 0.449180, loss_classifier: 0.294306, loss_box_reg: 0.154874
# Epoch: 1, Progress: 800/2501, Loss: 1.153119, loss_classifier: 0.917117, loss_box_reg: 0.236002
# Epoch: 1, Progress: 810/2501, Loss: 0.356476, loss_classifier: 0.252228, loss_box_reg: 0.104248
# Epoch: 1, Progress: 820/2501, Loss: 1.159396, loss_classifier: 0.941396, loss_box_reg: 0.218000
# Epoch: 1, Progress: 830/2501, Loss: 0.569274, loss_classifier: 0.434083, loss_box_reg: 0.135191
# Epoch: 1, Progress: 840/2501, Loss: 1.111791, loss_classifier: 0.908458, loss_box_reg: 0.203332
# Epoch: 1, Progress: 850/2501, Loss: 0.413722, loss_classifier: 0.245219, loss_box_reg: 0.168503
# Epoch: 1, Progress: 860/2501, Loss: 0.477964, loss_classifier: 0.355931, loss_box_reg: 0.122032
# Epoch: 1, Progress: 870/2501, Loss: 1.071544, loss_classifier: 0.807186, loss_box_reg: 0.264358
# Epoch: 1, Progress: 880/2501, Loss: 0.833596, loss_classifier: 0.643095, loss_box_reg: 0.190500
# Epoch: 1, Progress: 890/2501, Loss: 1.040535, loss_classifier: 0.815441, loss_box_reg: 0.225094
# Epoch: 1, Progress: 900/2501, Loss: 1.004255, loss_classifier: 0.807176, loss_box_reg: 0.197079
# Epoch: 1, Progress: 910/2501, Loss: 0.784817, loss_classifier: 0.610487, loss_box_reg: 0.174330
# Epoch: 1, Progress: 920/2501, Loss: 0.746096, loss_classifier: 0.555103, loss_box_reg: 0.190993
# Epoch: 1, Progress: 930/2501, Loss: 2.355905, loss_classifier: 2.076514, loss_box_reg: 0.279391
# Epoch: 1, Progress: 940/2501, Loss: 1.250460, loss_classifier: 0.954946, loss_box_reg: 0.295514
# Epoch: 1, Progress: 950/2501, Loss: 1.188012, loss_classifier: 0.937703, loss_box_reg: 0.250310
# Epoch: 1, Progress: 960/2501, Loss: 1.290713, loss_classifier: 1.050157, loss_box_reg: 0.240556
# Epoch: 1, Progress: 970/2501, Loss: 1.700155, loss_classifier: 1.470988, loss_box_reg: 0.229167
# Epoch: 1, Progress: 980/2501, Loss: 0.686586, loss_classifier: 0.511601, loss_box_reg: 0.174985
# Epoch: 1, Progress: 990/2501, Loss: 2.078444, loss_classifier: 1.746397, loss_box_reg: 0.332047
# Epoch: 1, Progress: 1000/2501, Loss: 0.939821, loss_classifier: 0.726509, loss_box_reg: 0.213312
# Epoch: 1, Progress: 1010/2501, Loss: 0.773006, loss_classifier: 0.631547, loss_box_reg: 0.141459
# Epoch: 1, Progress: 1020/2501, Loss: 1.625804, loss_classifier: 1.283355, loss_box_reg: 0.342450
# Epoch: 1, Progress: 1030/2501, Loss: 1.403165, loss_classifier: 1.158275, loss_box_reg: 0.244889
# Epoch: 1, Progress: 1040/2501, Loss: 1.442327, loss_classifier: 1.165473, loss_box_reg: 0.276854
# Epoch: 1, Progress: 1050/2501, Loss: 0.663392, loss_classifier: 0.508057, loss_box_reg: 0.155334
# Epoch: 1, Progress: 1060/2501, Loss: 1.056215, loss_classifier: 0.807688, loss_box_reg: 0.248527
# Epoch: 1, Progress: 1070/2501, Loss: 0.805981, loss_classifier: 0.594161, loss_box_reg: 0.211820
# Epoch: 1, Progress: 1080/2501, Loss: 1.192312, loss_classifier: 0.968693, loss_box_reg: 0.223619
# Epoch: 1, Progress: 1090/2501, Loss: 1.843732, loss_classifier: 1.547151, loss_box_reg: 0.296581
# Epoch: 1, Progress: 1100/2501, Loss: 1.070709, loss_classifier: 0.821185, loss_box_reg: 0.249524
# Epoch: 1, Progress: 1110/2501, Loss: 0.704323, loss_classifier: 0.498144, loss_box_reg: 0.206178
# Epoch: 1, Progress: 1120/2501, Loss: 0.577386, loss_classifier: 0.368133, loss_box_reg: 0.209254
# Epoch: 1, Progress: 1130/2501, Loss: 1.179061, loss_classifier: 0.935816, loss_box_reg: 0.243245
# Epoch: 1, Progress: 1140/2501, Loss: 1.112861, loss_classifier: 0.821480, loss_box_reg: 0.291380
# Epoch: 1, Progress: 1150/2501, Loss: 0.542005, loss_classifier: 0.382467, loss_box_reg: 0.159539
# Epoch: 1, Progress: 1160/2501, Loss: 1.108301, loss_classifier: 0.832085, loss_box_reg: 0.276216
# Epoch: 1, Progress: 1170/2501, Loss: 0.794817, loss_classifier: 0.579243, loss_box_reg: 0.215574
# Epoch: 1, Progress: 1180/2501, Loss: 1.047487, loss_classifier: 0.848532, loss_box_reg: 0.198955
# Epoch: 1, Progress: 1190/2501, Loss: 0.726098, loss_classifier: 0.557814, loss_box_reg: 0.168284
# Epoch: 1, Progress: 1200/2501, Loss: 0.665621, loss_classifier: 0.492359, loss_box_reg: 0.173262
# Epoch: 1, Progress: 1210/2501, Loss: 0.787924, loss_classifier: 0.568772, loss_box_reg: 0.219152
# Epoch: 1, Progress: 1220/2501, Loss: 1.645141, loss_classifier: 1.334751, loss_box_reg: 0.310391
# Epoch: 1, Progress: 1230/2501, Loss: 1.023605, loss_classifier: 0.791889, loss_box_reg: 0.231716
# Epoch: 1, Progress: 1240/2501, Loss: 0.459439, loss_classifier: 0.314798, loss_box_reg: 0.144641
# Epoch: 1, Progress: 1250/2501, Loss: 1.089628, loss_classifier: 0.881469, loss_box_reg: 0.208159
# Epoch: 1, Progress: 1260/2501, Loss: 0.367895, loss_classifier: 0.229623, loss_box_reg: 0.138272
# Epoch: 1, Progress: 1270/2501, Loss: 1.688853, loss_classifier: 1.358524, loss_box_reg: 0.330329
# Epoch: 1, Progress: 1280/2501, Loss: 0.648118, loss_classifier: 0.493654, loss_box_reg: 0.154464
# Epoch: 1, Progress: 1290/2501, Loss: 0.491644, loss_classifier: 0.329363, loss_box_reg: 0.162280
# Epoch: 1, Progress: 1300/2501, Loss: 2.041811, loss_classifier: 1.676589, loss_box_reg: 0.365223
# Epoch: 1, Progress: 1310/2501, Loss: 0.751294, loss_classifier: 0.587335, loss_box_reg: 0.163959
# Epoch: 1, Progress: 1320/2501, Loss: 1.660882, loss_classifier: 1.352381, loss_box_reg: 0.308501
# Epoch: 1, Progress: 1330/2501, Loss: 1.336849, loss_classifier: 1.088592, loss_box_reg: 0.248257
# Epoch: 1, Progress: 1340/2501, Loss: 0.518263, loss_classifier: 0.325456, loss_box_reg: 0.192807
# Epoch: 1, Progress: 1350/2501, Loss: 0.848293, loss_classifier: 0.668813, loss_box_reg: 0.179480
# Epoch: 1, Progress: 1360/2501, Loss: 0.330863, loss_classifier: 0.230414, loss_box_reg: 0.100449
# Epoch: 1, Progress: 1370/2501, Loss: 1.187005, loss_classifier: 0.956924, loss_box_reg: 0.230082
# Epoch: 1, Progress: 1380/2501, Loss: 0.542983, loss_classifier: 0.421483, loss_box_reg: 0.121501
# Epoch: 1, Progress: 1390/2501, Loss: 2.349954, loss_classifier: 2.029335, loss_box_reg: 0.320618
# Epoch: 1, Progress: 1400/2501, Loss: 0.900532, loss_classifier: 0.678483, loss_box_reg: 0.222049
# Epoch: 1, Progress: 1410/2501, Loss: 1.082356, loss_classifier: 0.900205, loss_box_reg: 0.182151
# Epoch: 1, Progress: 1420/2501, Loss: 0.616692, loss_classifier: 0.449995, loss_box_reg: 0.166698
# Epoch: 1, Progress: 1430/2501, Loss: 0.967963, loss_classifier: 0.796647, loss_box_reg: 0.171317
# Epoch: 1, Progress: 1440/2501, Loss: 0.828895, loss_classifier: 0.584162, loss_box_reg: 0.244733
# Epoch: 1, Progress: 1450/2501, Loss: 0.763049, loss_classifier: 0.538570, loss_box_reg: 0.224480
# Epoch: 1, Progress: 1460/2501, Loss: 0.958774, loss_classifier: 0.737114, loss_box_reg: 0.221660
# Epoch: 1, Progress: 1470/2501, Loss: 1.437091, loss_classifier: 1.149518, loss_box_reg: 0.287573
# Epoch: 1, Progress: 1480/2501, Loss: 1.331381, loss_classifier: 1.105315, loss_box_reg: 0.226066
# Epoch: 1, Progress: 1490/2501, Loss: 0.819567, loss_classifier: 0.585602, loss_box_reg: 0.233965
# Epoch: 1, Progress: 1500/2501, Loss: 0.208992, loss_classifier: 0.100405, loss_box_reg: 0.108587
# Epoch: 1, Progress: 1510/2501, Loss: 0.622436, loss_classifier: 0.399841, loss_box_reg: 0.222595
# Epoch: 1, Progress: 1520/2501, Loss: 0.440525, loss_classifier: 0.311262, loss_box_reg: 0.129263
# Epoch: 1, Progress: 1530/2501, Loss: 0.819108, loss_classifier: 0.648009, loss_box_reg: 0.171099
# Epoch: 1, Progress: 1540/2501, Loss: 0.533298, loss_classifier: 0.397771, loss_box_reg: 0.135527
# Epoch: 1, Progress: 1550/2501, Loss: 0.987781, loss_classifier: 0.807041, loss_box_reg: 0.180740
# Epoch: 1, Progress: 1560/2501, Loss: 1.760025, loss_classifier: 1.443977, loss_box_reg: 0.316047
# Epoch: 1, Progress: 1570/2501, Loss: 1.309955, loss_classifier: 1.060630, loss_box_reg: 0.249324
# Epoch: 1, Progress: 1580/2501, Loss: 0.493728, loss_classifier: 0.332369, loss_box_reg: 0.161359
# Epoch: 1, Progress: 1590/2501, Loss: 1.408604, loss_classifier: 1.124575, loss_box_reg: 0.284029
# Epoch: 1, Progress: 1600/2501, Loss: 1.095430, loss_classifier: 0.826946, loss_box_reg: 0.268484
# Epoch: 1, Progress: 1610/2501, Loss: 1.787226, loss_classifier: 1.474176, loss_box_reg: 0.313050
# Epoch: 1, Progress: 1620/2501, Loss: 1.305422, loss_classifier: 1.035702, loss_box_reg: 0.269720
# Epoch: 1, Progress: 1630/2501, Loss: 1.030545, loss_classifier: 0.805674, loss_box_reg: 0.224871
# Epoch: 1, Progress: 1640/2501, Loss: 0.409117, loss_classifier: 0.257932, loss_box_reg: 0.151185
# Epoch: 1, Progress: 1650/2501, Loss: 0.769786, loss_classifier: 0.561635, loss_box_reg: 0.208151
# Epoch: 1, Progress: 1660/2501, Loss: 1.414865, loss_classifier: 1.143225, loss_box_reg: 0.271641
# Epoch: 1, Progress: 1670/2501, Loss: 1.000186, loss_classifier: 0.747935, loss_box_reg: 0.252251
# Epoch: 1, Progress: 1680/2501, Loss: 0.756475, loss_classifier: 0.518882, loss_box_reg: 0.237593
# Epoch: 1, Progress: 1690/2501, Loss: 1.168589, loss_classifier: 0.921673, loss_box_reg: 0.246916
# Epoch: 1, Progress: 1700/2501, Loss: 0.746581, loss_classifier: 0.562425, loss_box_reg: 0.184156
# Epoch: 1, Progress: 1710/2501, Loss: 2.435641, loss_classifier: 2.228490, loss_box_reg: 0.207151
# Epoch: 1, Progress: 1720/2501, Loss: 0.790731, loss_classifier: 0.601419, loss_box_reg: 0.189312
# Epoch: 1, Progress: 1730/2501, Loss: 0.715594, loss_classifier: 0.502384, loss_box_reg: 0.213210
# Epoch: 1, Progress: 1740/2501, Loss: 1.470868, loss_classifier: 1.213229, loss_box_reg: 0.257639
# Epoch: 1, Progress: 1750/2501, Loss: 0.730157, loss_classifier: 0.544264, loss_box_reg: 0.185894
# Epoch: 1, Progress: 1760/2501, Loss: 2.146135, loss_classifier: 1.820703, loss_box_reg: 0.325432
# Epoch: 1, Progress: 1770/2501, Loss: 1.281255, loss_classifier: 1.023840, loss_box_reg: 0.257416
# Epoch: 1, Progress: 1780/2501, Loss: 1.722724, loss_classifier: 1.447468, loss_box_reg: 0.275256
# Epoch: 1, Progress: 1790/2501, Loss: 0.699385, loss_classifier: 0.511909, loss_box_reg: 0.187476
# Epoch: 1, Progress: 1800/2501, Loss: 1.782865, loss_classifier: 1.554011, loss_box_reg: 0.228855
# Epoch: 1, Progress: 1810/2501, Loss: 1.844338, loss_classifier: 1.542554, loss_box_reg: 0.301784
# Epoch: 1, Progress: 1820/2501, Loss: 1.473130, loss_classifier: 1.222844, loss_box_reg: 0.250285
# Epoch: 1, Progress: 1830/2501, Loss: 1.556294, loss_classifier: 1.244203, loss_box_reg: 0.312091
# Epoch: 1, Progress: 1840/2501, Loss: 0.640862, loss_classifier: 0.506443, loss_box_reg: 0.134418
# Epoch: 1, Progress: 1850/2501, Loss: 1.424761, loss_classifier: 1.134216, loss_box_reg: 0.290545
# Epoch: 1, Progress: 1860/2501, Loss: 1.024282, loss_classifier: 0.800756, loss_box_reg: 0.223526
# Epoch: 1, Progress: 1870/2501, Loss: 0.659325, loss_classifier: 0.483110, loss_box_reg: 0.176215
# Epoch: 1, Progress: 1880/2501, Loss: 0.478938, loss_classifier: 0.340036, loss_box_reg: 0.138902
# Epoch: 1, Progress: 1890/2501, Loss: 2.220973, loss_classifier: 1.562582, loss_box_reg: 0.658391
# Epoch: 1, Progress: 1900/2501, Loss: 1.165470, loss_classifier: 0.936268, loss_box_reg: 0.229203
# Epoch: 1, Progress: 1910/2501, Loss: 0.598425, loss_classifier: 0.428195, loss_box_reg: 0.170230
# Epoch: 1, Progress: 1920/2501, Loss: 1.498231, loss_classifier: 1.189211, loss_box_reg: 0.309020
# Epoch: 1, Progress: 1930/2501, Loss: 1.370335, loss_classifier: 1.081599, loss_box_reg: 0.288736
# Epoch: 1, Progress: 1940/2501, Loss: 0.899593, loss_classifier: 0.708810, loss_box_reg: 0.190784
# Epoch: 1, Progress: 1950/2501, Loss: 0.492578, loss_classifier: 0.319117, loss_box_reg: 0.173461
# Epoch: 1, Progress: 1960/2501, Loss: 0.990582, loss_classifier: 0.797914, loss_box_reg: 0.192668
# Epoch: 1, Progress: 1970/2501, Loss: 1.108294, loss_classifier: 0.870461, loss_box_reg: 0.237832
# Epoch: 1, Progress: 1980/2501, Loss: 0.763239, loss_classifier: 0.517437, loss_box_reg: 0.245802
# Epoch: 1, Progress: 1990/2501, Loss: 1.059777, loss_classifier: 0.798695, loss_box_reg: 0.261082
# Epoch: 1, Progress: 2000/2501, Loss: 0.278953, loss_classifier: 0.147968, loss_box_reg: 0.130985
# Epoch: 1, Progress: 2010/2501, Loss: 0.648704, loss_classifier: 0.454937, loss_box_reg: 0.193767
# Epoch: 1, Progress: 2020/2501, Loss: 0.797319, loss_classifier: 0.563087, loss_box_reg: 0.234231
# Epoch: 1, Progress: 2030/2501, Loss: 0.632883, loss_classifier: 0.335276, loss_box_reg: 0.297606
# Epoch: 1, Progress: 2040/2501, Loss: 0.867851, loss_classifier: 0.696571, loss_box_reg: 0.171281
# Epoch: 1, Progress: 2050/2501, Loss: 0.453498, loss_classifier: 0.329917, loss_box_reg: 0.123582
# Epoch: 1, Progress: 2060/2501, Loss: 0.923790, loss_classifier: 0.716026, loss_box_reg: 0.207764
# Epoch: 1, Progress: 2070/2501, Loss: 1.194362, loss_classifier: 0.978284, loss_box_reg: 0.216078
# Epoch: 1, Progress: 2080/2501, Loss: 1.562341, loss_classifier: 1.279833, loss_box_reg: 0.282508
# Epoch: 1, Progress: 2090/2501, Loss: 0.688083, loss_classifier: 0.482833, loss_box_reg: 0.205250
# Epoch: 1, Progress: 2100/2501, Loss: 0.381874, loss_classifier: 0.245554, loss_box_reg: 0.136320
# Epoch: 1, Progress: 2110/2501, Loss: 0.516145, loss_classifier: 0.321302, loss_box_reg: 0.194842
# Epoch: 1, Progress: 2120/2501, Loss: 0.802705, loss_classifier: 0.589407, loss_box_reg: 0.213298
# Epoch: 1, Progress: 2130/2501, Loss: 1.130484, loss_classifier: 0.863987, loss_box_reg: 0.266497
# Epoch: 1, Progress: 2140/2501, Loss: 0.335451, loss_classifier: 0.215798, loss_box_reg: 0.119653
# Epoch: 1, Progress: 2150/2501, Loss: 0.512810, loss_classifier: 0.315453, loss_box_reg: 0.197357
# Epoch: 1, Progress: 2160/2501, Loss: 1.182206, loss_classifier: 0.949529, loss_box_reg: 0.232677
# Epoch: 1, Progress: 2170/2501, Loss: 0.686713, loss_classifier: 0.502158, loss_box_reg: 0.184555
# Epoch: 1, Progress: 2180/2501, Loss: 1.642759, loss_classifier: 1.467171, loss_box_reg: 0.175588
# Epoch: 1, Progress: 2190/2501, Loss: 1.473104, loss_classifier: 1.143794, loss_box_reg: 0.329310
# Epoch: 1, Progress: 2200/2501, Loss: 1.326366, loss_classifier: 1.053937, loss_box_reg: 0.272429
# Epoch: 1, Progress: 2210/2501, Loss: 1.315573, loss_classifier: 1.024925, loss_box_reg: 0.290648
# Epoch: 1, Progress: 2220/2501, Loss: 1.562171, loss_classifier: 1.330217, loss_box_reg: 0.231954
# Epoch: 1, Progress: 2230/2501, Loss: 0.645121, loss_classifier: 0.502118, loss_box_reg: 0.143003
# Epoch: 1, Progress: 2240/2501, Loss: 0.624411, loss_classifier: 0.472531, loss_box_reg: 0.151880
# Epoch: 1, Progress: 2250/2501, Loss: 0.708342, loss_classifier: 0.494175, loss_box_reg: 0.214167
# Epoch: 1, Progress: 2260/2501, Loss: 0.780376, loss_classifier: 0.549806, loss_box_reg: 0.230570
# Epoch: 1, Progress: 2270/2501, Loss: 3.240079, loss_classifier: 2.806144, loss_box_reg: 0.433935
# Epoch: 1, Progress: 2280/2501, Loss: 0.924623, loss_classifier: 0.749438, loss_box_reg: 0.175185
# Epoch: 1, Progress: 2290/2501, Loss: 0.572945, loss_classifier: 0.356571, loss_box_reg: 0.216374
# Epoch: 1, Progress: 2300/2501, Loss: 1.934611, loss_classifier: 1.635065, loss_box_reg: 0.299545
# Epoch: 1, Progress: 2310/2501, Loss: 2.396570, loss_classifier: 2.084858, loss_box_reg: 0.311712
# Epoch: 1, Progress: 2320/2501, Loss: 1.173361, loss_classifier: 0.941559, loss_box_reg: 0.231802
# Epoch: 1, Progress: 2330/2501, Loss: 0.942878, loss_classifier: 0.698492, loss_box_reg: 0.244387
# Epoch: 1, Progress: 2340/2501, Loss: 0.655117, loss_classifier: 0.512028, loss_box_reg: 0.143089
# Epoch: 1, Progress: 2350/2501, Loss: 0.783266, loss_classifier: 0.533926, loss_box_reg: 0.249340
# Epoch: 1, Progress: 2360/2501, Loss: 1.158067, loss_classifier: 0.964804, loss_box_reg: 0.193263
# Epoch: 1, Progress: 2370/2501, Loss: 1.348944, loss_classifier: 1.084497, loss_box_reg: 0.264446
# Epoch: 1, Progress: 2380/2501, Loss: 1.081174, loss_classifier: 0.811725, loss_box_reg: 0.269449
# Epoch: 1, Progress: 2390/2501, Loss: 0.823550, loss_classifier: 0.589709, loss_box_reg: 0.233841
# Epoch: 1, Progress: 2400/2501, Loss: 1.171021, loss_classifier: 0.857603, loss_box_reg: 0.313417
# Epoch: 1, Progress: 2410/2501, Loss: 1.176064, loss_classifier: 0.944169, loss_box_reg: 0.231895
# Epoch: 1, Progress: 2420/2501, Loss: 0.696122, loss_classifier: 0.535710, loss_box_reg: 0.160412
# Epoch: 1, Progress: 2430/2501, Loss: 1.023844, loss_classifier: 0.822406, loss_box_reg: 0.201437
# Epoch: 1, Progress: 2440/2501, Loss: 1.066501, loss_classifier: 0.812511, loss_box_reg: 0.253990
# Epoch: 1, Progress: 2450/2501, Loss: 1.362106, loss_classifier: 1.126239, loss_box_reg: 0.235867
# ...
# Epoch: 3, Progress: 1140/2501, Loss: 0.815157, loss_classifier: 0.567459, loss_box_reg: 0.247698
# Epoch: 3, Progress: 1150/2501, Loss: 2.849120, loss_classifier: 2.547761, loss_box_reg: 0.301358
# Epoch: 3, Progress: 1160/2501, Loss: 0.404654, loss_classifier: 0.257824, loss_box_reg: 0.146830
# Epoch: 3, Progress: 1170/2501, Loss: 0.896381, loss_classifier: 0.654634, loss_box_reg: 0.241747
# Epoch: 3, Progress: 1180/2501, Loss: 1.265589, loss_classifier: 0.968870, loss_box_reg: 0.296719
# Epoch: 3, Progress: 1190/2501, Loss: 1.152281, loss_classifier: 0.868446, loss_box_reg: 0.283835
# Epoch: 3, Progress: 1200/2501, Loss: 4.931118, loss_classifier: 4.696028, loss_box_reg: 0.235090
# Epoch: 3, Progress: 1210/2501, Loss: 0.967743, loss_classifier: 0.713291, loss_box_reg: 0.254453
# Epoch: 3, Progress: 1220/2501, Loss: 0.807442, loss_classifier: 0.560801, loss_box_reg: 0.246641
# Epoch: 3, Progress: 1230/2501, Loss: 2.959579, loss_classifier: 2.714435, loss_box_reg: 0.245143
# Epoch: 3, Progress: 1240/2501, Loss: 1.696142, loss_classifier: 1.357038, loss_box_reg: 0.339104
# Epoch: 3, Progress: 1250/2501, Loss: 1.814002, loss_classifier: 1.458140, loss_box_reg: 0.355862
# Epoch: 3, Progress: 1260/2501, Loss: 1.463736, loss_classifier: 1.172555, loss_box_reg: 0.291181
# Epoch: 3, Progress: 1270/2501, Loss: 1.445923, loss_classifier: 1.140850, loss_box_reg: 0.305072
# Epoch: 3, Progress: 1280/2501, Loss: 0.747713, loss_classifier: 0.501710, loss_box_reg: 0.246004
# Epoch: 3, Progress: 1290/2501, Loss: 1.323185, loss_classifier: 1.101428, loss_box_reg: 0.221757
# Epoch: 3, Progress: 1300/2501, Loss: 0.809404, loss_classifier: 0.603329, loss_box_reg: 0.206075
# Epoch: 3, Progress: 1310/2501, Loss: 1.072891, loss_classifier: 0.805941, loss_box_reg: 0.266950
# Epoch: 3, Progress: 1320/2501, Loss: 0.895968, loss_classifier: 0.695133, loss_box_reg: 0.200835
# Epoch: 3, Progress: 1330/2501, Loss: 0.950991, loss_classifier: 0.722074, loss_box_reg: 0.228917
# Epoch: 3, Progress: 1340/2501, Loss: 0.799549, loss_classifier: 0.609035, loss_box_reg: 0.190515
# Epoch: 3, Progress: 1350/2501, Loss: 1.269851, loss_classifier: 1.088261, loss_box_reg: 0.181591
# Epoch: 3, Progress: 1360/2501, Loss: 0.520697, loss_classifier: 0.336936, loss_box_reg: 0.183761
# Epoch: 3, Progress: 1370/2501, Loss: 0.612213, loss_classifier: 0.414323, loss_box_reg: 0.197890
# Epoch: 3, Progress: 1380/2501, Loss: 1.455476, loss_classifier: 1.194833, loss_box_reg: 0.260643
# Epoch: 3, Progress: 1390/2501, Loss: 0.515530, loss_classifier: 0.345027, loss_box_reg: 0.170503
# Epoch: 3, Progress: 1400/2501, Loss: 0.861076, loss_classifier: 0.677096, loss_box_reg: 0.183979
# Epoch: 3, Progress: 1410/2501, Loss: 0.908250, loss_classifier: 0.746384, loss_box_reg: 0.161866
# Epoch: 3, Progress: 1420/2501, Loss: 1.283537, loss_classifier: 1.043587, loss_box_reg: 0.239950
# Epoch: 3, Progress: 1430/2501, Loss: 4.549797, loss_classifier: 4.249974, loss_box_reg: 0.299822
# Epoch: 3, Progress: 1440/2501, Loss: 1.215544, loss_classifier: 1.008232, loss_box_reg: 0.207312
# Epoch: 3, Progress: 1450/2501, Loss: 1.095488, loss_classifier: 0.852148, loss_box_reg: 0.243339
# Epoch: 3, Progress: 1460/2501, Loss: 1.665410, loss_classifier: 1.390388, loss_box_reg: 0.275021
# Epoch: 3, Progress: 1470/2501, Loss: 0.887361, loss_classifier: 0.625633, loss_box_reg: 0.261728
# Epoch: 3, Progress: 1480/2501, Loss: 1.059657, loss_classifier: 0.786178, loss_box_reg: 0.273479
# Epoch: 3, Progress: 1490/2501, Loss: 0.376081, loss_classifier: 0.235410, loss_box_reg: 0.140671
# Epoch: 3, Progress: 1500/2501, Loss: 0.356277, loss_classifier: 0.204097, loss_box_reg: 0.152181
# Epoch: 3, Progress: 1510/2501, Loss: 1.411262, loss_classifier: 1.175261, loss_box_reg: 0.236001
# Epoch: 3, Progress: 1520/2501, Loss: 0.968022, loss_classifier: 0.742193, loss_box_reg: 0.225829
# Epoch: 3, Progress: 1530/2501, Loss: 0.859038, loss_classifier: 0.684776, loss_box_reg: 0.174262
# Epoch: 3, Progress: 1540/2501, Loss: 1.907622, loss_classifier: 1.563788, loss_box_reg: 0.343834
# Epoch: 3, Progress: 1550/2501, Loss: 1.540991, loss_classifier: 1.256647, loss_box_reg: 0.284344
# Epoch: 3, Progress: 1560/2501, Loss: 1.265920, loss_classifier: 1.043962, loss_box_reg: 0.221957
# Epoch: 3, Progress: 1570/2501, Loss: 0.709452, loss_classifier: 0.506362, loss_box_reg: 0.203090
# Epoch: 3, Progress: 1580/2501, Loss: 0.244458, loss_classifier: 0.115790, loss_box_reg: 0.128668
# Epoch: 3, Progress: 1590/2501, Loss: 0.582031, loss_classifier: 0.384230, loss_box_reg: 0.197801
# Epoch: 3, Progress: 1600/2501, Loss: 2.300414, loss_classifier: 1.884002, loss_box_reg: 0.416412
# Epoch: 3, Progress: 1610/2501, Loss: 1.366122, loss_classifier: 1.118023, loss_box_reg: 0.248099
# Epoch: 3, Progress: 1620/2501, Loss: 1.380396, loss_classifier: 1.026572, loss_box_reg: 0.353824
# Epoch: 3, Progress: 1630/2501, Loss: 1.647276, loss_classifier: 1.405907, loss_box_reg: 0.241369
# Epoch: 3, Progress: 1640/2501, Loss: 1.045351, loss_classifier: 0.789137, loss_box_reg: 0.256213
# Epoch: 3, Progress: 1650/2501, Loss: 1.443551, loss_classifier: 1.213068, loss_box_reg: 0.230483
# Epoch: 3, Progress: 1660/2501, Loss: 0.748178, loss_classifier: 0.527832, loss_box_reg: 0.220346
# Epoch: 3, Progress: 1670/2501, Loss: 1.298687, loss_classifier: 1.061953, loss_box_reg: 0.236734
# Epoch: 3, Progress: 1680/2501, Loss: 1.227788, loss_classifier: 0.972938, loss_box_reg: 0.254850
# Epoch: 3, Progress: 1690/2501, Loss: 0.679611, loss_classifier: 0.489073, loss_box_reg: 0.190538
# Epoch: 3, Progress: 1700/2501, Loss: 0.797275, loss_classifier: 0.608325, loss_box_reg: 0.188950
# Epoch: 3, Progress: 1710/2501, Loss: 1.046403, loss_classifier: 0.867699, loss_box_reg: 0.178705
# Epoch: 3, Progress: 1720/2501, Loss: 0.477111, loss_classifier: 0.291511, loss_box_reg: 0.185600
# Epoch: 3, Progress: 1730/2501, Loss: 1.037676, loss_classifier: 0.837060, loss_box_reg: 0.200617
# Epoch: 3, Progress: 1740/2501, Loss: 2.009096, loss_classifier: 1.771793, loss_box_reg: 0.237302
# Epoch: 3, Progress: 1750/2501, Loss: 0.654153, loss_classifier: 0.489767, loss_box_reg: 0.164386
# Epoch: 3, Progress: 1760/2501, Loss: 0.875383, loss_classifier: 0.661880, loss_box_reg: 0.213503
# Epoch: 3, Progress: 1770/2501, Loss: 2.246223, loss_classifier: 1.908517, loss_box_reg: 0.337706
# Epoch: 3, Progress: 1780/2501, Loss: 0.629129, loss_classifier: 0.477900, loss_box_reg: 0.151229
# Epoch: 3, Progress: 1790/2501, Loss: 0.507785, loss_classifier: 0.317924, loss_box_reg: 0.189861
# Epoch: 3, Progress: 1800/2501, Loss: 1.674556, loss_classifier: 1.332839, loss_box_reg: 0.341718
# Epoch: 3, Progress: 1810/2501, Loss: 1.650547, loss_classifier: 1.397817, loss_box_reg: 0.252729
# Epoch: 3, Progress: 1820/2501, Loss: 2.075229, loss_classifier: 1.714679, loss_box_reg: 0.360550
# Epoch: 3, Progress: 1830/2501, Loss: 1.501189, loss_classifier: 1.259199, loss_box_reg: 0.241990
# Epoch: 3, Progress: 1840/2501, Loss: 0.458653, loss_classifier: 0.257908, loss_box_reg: 0.200745
# Epoch: 3, Progress: 1850/2501, Loss: 0.835021, loss_classifier: 0.640361, loss_box_reg: 0.194660
# Epoch: 3, Progress: 1860/2501, Loss: 0.888690, loss_classifier: 0.671969, loss_box_reg: 0.216721
# Epoch: 3, Progress: 1870/2501, Loss: 1.219354, loss_classifier: 1.066945, loss_box_reg: 0.152409
# Epoch: 3, Progress: 1880/2501, Loss: 1.391754, loss_classifier: 1.235230, loss_box_reg: 0.156524
# Epoch: 3, Progress: 1890/2501, Loss: 0.953290, loss_classifier: 0.715991, loss_box_reg: 0.237299
# Epoch: 3, Progress: 1900/2501, Loss: 1.932565, loss_classifier: 1.681817, loss_box_reg: 0.250749
# Epoch: 3, Progress: 1910/2501, Loss: 1.105270, loss_classifier: 0.828758, loss_box_reg: 0.276511
# Epoch: 3, Progress: 1920/2501, Loss: 1.752520, loss_classifier: 1.446963, loss_box_reg: 0.305556
# Epoch: 3, Progress: 1930/2501, Loss: 0.370942, loss_classifier: 0.225055, loss_box_reg: 0.145886
# Epoch: 3, Progress: 1940/2501, Loss: 0.999714, loss_classifier: 0.824226, loss_box_reg: 0.175488
# Epoch: 3, Progress: 1950/2501, Loss: 0.716869, loss_classifier: 0.534543, loss_box_reg: 0.182326
# Epoch: 3, Progress: 1960/2501, Loss: 0.460864, loss_classifier: 0.354936, loss_box_reg: 0.105928
# Epoch: 3, Progress: 1970/2501, Loss: 0.952492, loss_classifier: 0.767087, loss_box_reg: 0.185405
# Epoch: 3, Progress: 1980/2501, Loss: 0.789809, loss_classifier: 0.592443, loss_box_reg: 0.197367
# Epoch: 3, Progress: 1990/2501, Loss: 1.132532, loss_classifier: 0.873646, loss_box_reg: 0.258886
# Epoch: 3, Progress: 2000/2501, Loss: 1.582692, loss_classifier: 1.271105, loss_box_reg: 0.311587
# Epoch: 3, Progress: 2010/2501, Loss: 0.786680, loss_classifier: 0.591237, loss_box_reg: 0.195443
# Epoch: 3, Progress: 2020/2501, Loss: 0.428059, loss_classifier: 0.298307, loss_box_reg: 0.129752
# Epoch: 3, Progress: 2030/2501, Loss: 0.659527, loss_classifier: 0.462240, loss_box_reg: 0.197287
# Epoch: 3, Progress: 2040/2501, Loss: 2.233996, loss_classifier: 1.877706, loss_box_reg: 0.356290
# Epoch: 3, Progress: 2050/2501, Loss: 2.247235, loss_classifier: 1.929830, loss_box_reg: 0.317405
# Epoch: 3, Progress: 2060/2501, Loss: 1.921348, loss_classifier: 1.706544, loss_box_reg: 0.214803
# Epoch: 3, Progress: 2070/2501, Loss: 1.698225, loss_classifier: 1.416092, loss_box_reg: 0.282133
# Epoch: 3, Progress: 2080/2501, Loss: 1.145491, loss_classifier: 0.934514, loss_box_reg: 0.210977
# Epoch: 3, Progress: 2090/2501, Loss: 0.914400, loss_classifier: 0.673546, loss_box_reg: 0.240855
# Epoch: 3, Progress: 2100/2501, Loss: 1.115186, loss_classifier: 0.936817, loss_box_reg: 0.178369
# Epoch: 3, Progress: 2110/2501, Loss: 0.836203, loss_classifier: 0.606166, loss_box_reg: 0.230037
# Epoch: 3, Progress: 2120/2501, Loss: 0.832508, loss_classifier: 0.658851, loss_box_reg: 0.173658
# Epoch: 3, Progress: 2130/2501, Loss: 0.963810, loss_classifier: 0.773371, loss_box_reg: 0.190439
# Epoch: 3, Progress: 2140/2501, Loss: 0.380998, loss_classifier: 0.246698, loss_box_reg: 0.134300
# Epoch: 3, Progress: 2150/2501, Loss: 1.629458, loss_classifier: 1.361713, loss_box_reg: 0.267745
# Epoch: 3, Progress: 2160/2501, Loss: 0.478983, loss_classifier: 0.350733, loss_box_reg: 0.128250
# Epoch: 3, Progress: 2170/2501, Loss: 0.558315, loss_classifier: 0.397138, loss_box_reg: 0.161176
# Epoch: 3, Progress: 2180/2501, Loss: 1.085979, loss_classifier: 0.845364, loss_box_reg: 0.240614
# Epoch: 3, Progress: 2190/2501, Loss: 1.176585, loss_classifier: 1.006874, loss_box_reg: 0.169711
# Epoch: 3, Progress: 2200/2501, Loss: 0.874953, loss_classifier: 0.676041, loss_box_reg: 0.198912
# Epoch: 3, Progress: 2210/2501, Loss: 0.826725, loss_classifier: 0.616435, loss_box_reg: 0.210291
# Epoch: 3, Progress: 2220/2501, Loss: 0.505304, loss_classifier: 0.383322, loss_box_reg: 0.121982
# Epoch: 3, Progress: 2230/2501, Loss: 0.881811, loss_classifier: 0.690774, loss_box_reg: 0.191038
# Epoch: 3, Progress: 2240/2501, Loss: 1.310834, loss_classifier: 1.050807, loss_box_reg: 0.260027
# Epoch: 3, Progress: 2250/2501, Loss: 0.352597, loss_classifier: 0.197200, loss_box_reg: 0.155397
# Epoch: 3, Progress: 2260/2501, Loss: 1.299840, loss_classifier: 1.024898, loss_box_reg: 0.274942
# Epoch: 3, Progress: 2270/2501, Loss: 0.482790, loss_classifier: 0.344596, loss_box_reg: 0.138194
# Epoch: 3, Progress: 2280/2501, Loss: 0.858397, loss_classifier: 0.639340, loss_box_reg: 0.219057
# Epoch: 3, Progress: 2290/2501, Loss: 0.194411, loss_classifier: 0.063653, loss_box_reg: 0.130759
# Epoch: 3, Progress: 2300/2501, Loss: 0.124140, loss_classifier: 0.028645, loss_box_reg: 0.095494
# Epoch: 3, Progress: 2310/2501, Loss: 1.738917, loss_classifier: 1.416548, loss_box_reg: 0.322369
# Epoch: 3, Progress: 2320/2501, Loss: 0.495516, loss_classifier: 0.343489, loss_box_reg: 0.152027
# Epoch: 3, Progress: 2330/2501, Loss: 1.025964, loss_classifier: 0.791888, loss_box_reg: 0.234076
# Epoch: 3, Progress: 2340/2501, Loss: 1.231178, loss_classifier: 0.951519, loss_box_reg: 0.279659
# Epoch: 3, Progress: 2350/2501, Loss: 0.536390, loss_classifier: 0.371113, loss_box_reg: 0.165277
# Epoch: 3, Progress: 2360/2501, Loss: 0.973664, loss_classifier: 0.682748, loss_box_reg: 0.290916
# Epoch: 3, Progress: 2370/2501, Loss: 1.045217, loss_classifier: 0.837940, loss_box_reg: 0.207277
# Epoch: 3, Progress: 2380/2501, Loss: 0.623437, loss_classifier: 0.448431, loss_box_reg: 0.175005
# Epoch: 3, Progress: 2390/2501, Loss: 0.921788, loss_classifier: 0.741117, loss_box_reg: 0.180671
# Epoch: 3, Progress: 2400/2501, Loss: 0.445614, loss_classifier: 0.280660, loss_box_reg: 0.164953
# Epoch: 3, Progress: 2410/2501, Loss: 0.278498, loss_classifier: 0.166149, loss_box_reg: 0.112349
# Epoch: 3, Progress: 2420/2501, Loss: 1.174833, loss_classifier: 0.904405, loss_box_reg: 0.270428
# Epoch: 3, Progress: 2430/2501, Loss: 0.534747, loss_classifier: 0.378798, loss_box_reg: 0.155949
# Epoch: 3, Progress: 2440/2501, Loss: 0.388344, loss_classifier: 0.213709, loss_box_reg: 0.174635
# Epoch: 3, Progress: 2450/2501, Loss: 0.524245, loss_classifier: 0.285048, loss_box_reg: 0.239196
# Epoch: 3, Progress: 2460/2501, Loss: 1.619063, loss_classifier: 1.303961, loss_box_reg: 0.315101
# Epoch: 3, Progress: 2470/2501, Loss: 1.162380, loss_classifier: 0.911289, loss_box_reg: 0.251091
# Epoch: 3, Progress: 2480/2501, Loss: 1.475140, loss_classifier: 1.166976, loss_box_reg: 0.308165
# Epoch: 3, Progress: 2490/2501, Loss: 1.732864, loss_classifier: 1.452492, loss_box_reg: 0.280372
# Epoch: 3, Progress: 2500/2501, Loss: 1.198765, loss_classifier: 0.951308, loss_box_reg: 0.247456
# Epoch: 4, Progress: 10/2501, Loss: 0.350153, loss_classifier: 0.231145, loss_box_reg: 0.119008
# Epoch: 4, Progress: 20/2501, Loss: 0.618040, loss_classifier: 0.421004, loss_box_reg: 0.197036
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1ec03c984462> in <module>()
#       8     targets = [{k: v.to(dev) for k, v in t.items()} for t in targets]
#       9     model=model.train()
# ---> 10     out= model(images,targets)
#      11     l1, l2=out['classification'],out['bbox_regression']
#      12     loss=l1+l2
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-13-6d38a86bf152> in forward(self, images, targets)
#     543
#     544         # create the set of anchors
# --> 545         anchors = self.anchor_generator(images, features)
#     546
#     547         losses = {}
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/detection/anchor_utils.py in forward(self, image_list, feature_maps)
#     145         dtype, device = feature_maps[0].dtype, feature_maps[0].device
#     146         strides = [[torch.tensor(image_size[0] // g[0], dtype=torch.int64, device=device),
# --> 147                     torch.tensor(image_size[1] // g[1], dtype=torch.int64, device=device)] for g in grid_sizes]
#     148         self.set_cell_anchors(dtype, device)
#     149         anchors_over_all_feature_maps = self.cached_grid_anchors(grid_sizes, strides)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/detection/anchor_utils.py in <listcomp>(.0)
#     145         dtype, device = feature_maps[0].dtype, feature_maps[0].device
#     146         strides = [[torch.tensor(image_size[0] // g[0], dtype=torch.int64, device=device),
# --> 147                     torch.tensor(image_size[1] // g[1], dtype=torch.int64, device=device)] for g in grid_sizes]
#     148         self.set_cell_anchors(dtype, device)
#     149         anchors_over_all_feature_maps = self.cached_grid_anchors(grid_sizes, strides)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Eval

# %%
model = torch.load('/content/gdrive/MyDrive/CElossRetinaNet29.pth')
model=model.to(dev)
evaluate(model,test_loader,dev)
# Out:
# creating index...
# index created!
# Test:  [   0/2506]  eta: 0:13:57  model_time: 0.3136 (0.3136)  evaluator_time: 0.0055 (0.0055)  time: 0.3344  data: 0.0138  max mem: 3888
# Test:  [ 100/2506]  eta: 0:10:47  model_time: 0.2429 (0.2514)  evaluator_time: 0.0036 (0.0046)  time: 0.2775  data: 0.0111  max mem: 3888
# Test:  [ 200/2506]  eta: 0:10:30  model_time: 0.2484 (0.2557)  evaluator_time: 0.0041 (0.0050)  time: 0.2885  data: 0.0108  max mem: 3888
# Test:  [ 300/2506]  eta: 0:10:07  model_time: 0.2376 (0.2578)  evaluator_time: 0.0039 (0.0049)  time: 0.2661  data: 0.0110  max mem: 3888
# Test:  [ 400/2506]  eta: 0:09:44  model_time: 0.2466 (0.2598)  evaluator_time: 0.0040 (0.0052)  time: 0.2750  data: 0.0110  max mem: 3888
# Test:  [ 500/2506]  eta: 0:09:22  model_time: 0.2665 (0.2626)  evaluator_time: 0.0043 (0.0052)  time: 0.2952  data: 0.0109  max mem: 3888
# Test:  [ 600/2506]  eta: 0:08:59  model_time: 0.2584 (0.2653)  evaluator_time: 0.0038 (0.0051)  time: 0.3001  data: 0.0111  max mem: 3888
# Test:  [ 700/2506]  eta: 0:08:31  model_time: 0.2556 (0.2660)  evaluator_time: 0.0042 (0.0051)  time: 0.2802  data: 0.0109  max mem: 3888
# Test:  [ 800/2506]  eta: 0:08:06  model_time: 0.2561 (0.2673)  evaluator_time: 0.0037 (0.0051)  time: 0.2839  data: 0.0110  max mem: 3888
# Test:  [ 900/2506]  eta: 0:07:39  model_time: 0.2636 (0.2683)  evaluator_time: 0.0041 (0.0052)  time: 0.3015  data: 0.0108  max mem: 3888
# Test:  [1000/2506]  eta: 0:07:12  model_time: 0.2876 (0.2693)  evaluator_time: 0.0046 (0.0052)  time: 0.3205  data: 0.0107  max mem: 3888
# Test:  [1100/2506]  eta: 0:06:43  model_time: 0.2583 (0.2695)  evaluator_time: 0.0042 (0.0052)  time: 0.2979  data: 0.0110  max mem: 3888
# Test:  [1200/2506]  eta: 0:06:16  model_time: 0.2556 (0.2704)  evaluator_time: 0.0042 (0.0052)  time: 0.2876  data: 0.0115  max mem: 3888
# Test:  [1300/2506]  eta: 0:05:48  model_time: 0.2536 (0.2711)  evaluator_time: 0.0060 (0.0053)  time: 0.2979  data: 0.0110  max mem: 3888
# Test:  [1400/2506]  eta: 0:05:20  model_time: 0.2649 (0.2717)  evaluator_time: 0.0043 (0.0052)  time: 0.3017  data: 0.0114  max mem: 3888
# Test:  [1500/2506]  eta: 0:04:50  model_time: 0.2566 (0.2715)  evaluator_time: 0.0041 (0.0052)  time: 0.2849  data: 0.0110  max mem: 3888
# Test:  [1600/2506]  eta: 0:04:21  model_time: 0.2534 (0.2714)  evaluator_time: 0.0040 (0.0052)  time: 0.2804  data: 0.0112  max mem: 3888
# Test:  [1700/2506]  eta: 0:03:53  model_time: 0.2504 (0.2717)  evaluator_time: 0.0038 (0.0052)  time: 0.2861  data: 0.0115  max mem: 3888
# Test:  [1800/2506]  eta: 0:03:24  model_time: 0.2652 (0.2719)  evaluator_time: 0.0037 (0.0052)  time: 0.2975  data: 0.0107  max mem: 3888
# Test:  [1900/2506]  eta: 0:02:55  model_time: 0.2572 (0.2723)  evaluator_time: 0.0046 (0.0052)  time: 0.2903  data: 0.0112  max mem: 3888
# Test:  [2000/2506]  eta: 0:02:26  model_time: 0.2558 (0.2727)  evaluator_time: 0.0043 (0.0052)  time: 0.2904  data: 0.0109  max mem: 3888
# Test:  [2100/2506]  eta: 0:01:57  model_time: 0.2560 (0.2727)  evaluator_time: 0.0040 (0.0052)  time: 0.2959  data: 0.0106  max mem: 3888
# Test:  [2200/2506]  eta: 0:01:28  model_time: 0.2579 (0.2728)  evaluator_time: 0.0040 (0.0052)  time: 0.2965  data: 0.0113  max mem: 3888
# Test:  [2300/2506]  eta: 0:00:59  model_time: 0.2560 (0.2726)  evaluator_time: 0.0040 (0.0052)  time: 0.2825  data: 0.0108  max mem: 3888
# Test:  [2400/2506]  eta: 0:00:30  model_time: 0.2722 (0.2725)  evaluator_time: 0.0050 (0.0052)  time: 0.3018  data: 0.0113  max mem: 3888
# Test:  [2500/2506]  eta: 0:00:01  model_time: 0.2568 (0.2726)  evaluator_time: 0.0045 (0.0052)  time: 0.2933  data: 0.0111  max mem: 3888
# Test:  [2505/2506]  eta: 0:00:00  model_time: 0.2584 (0.2725)  evaluator_time: 0.0046 (0.0052)  time: 0.2873  data: 0.0110  max mem: 3888
# Test: Total time: 0:12:07 (0.2903 s / it)
# Averaged stats: model_time: 0.2584 (0.2725)  evaluator_time: 0.0046 (0.0052)
# Accumulating evaluation results...
# DONE (t=2.10s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.649
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.155
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.391
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.519

# %%
model = torch.load('/content/gdrive/MyDrive/CElossRetinaNet31.pth')
model=model.to(dev)
evaluate(model,test_loader,dev)
# Out:
# creating index...
# index created!
# Test:  [   0/2506]  eta: 0:12:44  model_time: 0.2839 (0.2839)  evaluator_time: 0.0070 (0.0070)  time: 0.3051  data: 0.0129  max mem: 3888
# Test:  [ 100/2506]  eta: 0:11:41  model_time: 0.2678 (0.2740)  evaluator_time: 0.0039 (0.0050)  time: 0.3042  data: 0.0117  max mem: 3888
# Test:  [ 200/2506]  eta: 0:11:16  model_time: 0.2665 (0.2750)  evaluator_time: 0.0041 (0.0057)  time: 0.3050  data: 0.0112  max mem: 3888
# Test:  [ 300/2506]  eta: 0:10:41  model_time: 0.2446 (0.2731)  evaluator_time: 0.0038 (0.0055)  time: 0.2719  data: 0.0107  max mem: 3888
# Test:  [ 400/2506]  eta: 0:10:13  model_time: 0.2597 (0.2730)  evaluator_time: 0.0039 (0.0057)  time: 0.2836  data: 0.0110  max mem: 3888
# Test:  [ 500/2506]  eta: 0:09:46  model_time: 0.2593 (0.2742)  evaluator_time: 0.0045 (0.0056)  time: 0.2980  data: 0.0111  max mem: 3888
# Test:  [ 600/2506]  eta: 0:09:18  model_time: 0.2571 (0.2751)  evaluator_time: 0.0038 (0.0055)  time: 0.2991  data: 0.0110  max mem: 3888
# Test:  [ 700/2506]  eta: 0:08:48  model_time: 0.2549 (0.2744)  evaluator_time: 0.0044 (0.0055)  time: 0.2811  data: 0.0111  max mem: 3888
# Test:  [ 800/2506]  eta: 0:08:19  model_time: 0.2529 (0.2747)  evaluator_time: 0.0037 (0.0055)  time: 0.2842  data: 0.0110  max mem: 3888
# Test:  [ 900/2506]  eta: 0:07:50  model_time: 0.2624 (0.2750)  evaluator_time: 0.0044 (0.0056)  time: 0.3031  data: 0.0106  max mem: 3888
# Test:  [1000/2506]  eta: 0:07:21  model_time: 0.2888 (0.2753)  evaluator_time: 0.0044 (0.0056)  time: 0.3181  data: 0.0105  max mem: 3888
# Test:  [1100/2506]  eta: 0:06:52  model_time: 0.2567 (0.2750)  evaluator_time: 0.0042 (0.0056)  time: 0.2960  data: 0.0108  max mem: 3888
# Test:  [1200/2506]  eta: 0:06:23  model_time: 0.2568 (0.2753)  evaluator_time: 0.0042 (0.0056)  time: 0.2884  data: 0.0111  max mem: 3888
# Test:  [1300/2506]  eta: 0:05:54  model_time: 0.2551 (0.2757)  evaluator_time: 0.0060 (0.0056)  time: 0.2991  data: 0.0109  max mem: 3888
# Test:  [1400/2506]  eta: 0:05:25  model_time: 0.2606 (0.2759)  evaluator_time: 0.0046 (0.0056)  time: 0.3023  data: 0.0112  max mem: 3888
# Test:  [1500/2506]  eta: 0:04:55  model_time: 0.2575 (0.2754)  evaluator_time: 0.0038 (0.0056)  time: 0.2851  data: 0.0110  max mem: 3888
# Test:  [1600/2506]  eta: 0:04:25  model_time: 0.2556 (0.2750)  evaluator_time: 0.0039 (0.0056)  time: 0.2807  data: 0.0111  max mem: 3888
# Test:  [1700/2506]  eta: 0:03:56  model_time: 0.2449 (0.2750)  evaluator_time: 0.0038 (0.0056)  time: 0.2848  data: 0.0113  max mem: 3888
# Test:  [1800/2506]  eta: 0:03:26  model_time: 0.2603 (0.2751)  evaluator_time: 0.0038 (0.0055)  time: 0.2986  data: 0.0110  max mem: 3888
# Test:  [1900/2506]  eta: 0:02:57  model_time: 0.2637 (0.2753)  evaluator_time: 0.0043 (0.0055)  time: 0.2903  data: 0.0110  max mem: 3888
# Test:  [2000/2506]  eta: 0:02:28  model_time: 0.2569 (0.2755)  evaluator_time: 0.0040 (0.0055)  time: 0.2917  data: 0.0109  max mem: 3888
# Test:  [2100/2506]  eta: 0:01:59  model_time: 0.2569 (0.2753)  evaluator_time: 0.0040 (0.0056)  time: 0.2965  data: 0.0106  max mem: 3888
# Test:  [2200/2506]  eta: 0:01:29  model_time: 0.2602 (0.2754)  evaluator_time: 0.0041 (0.0056)  time: 0.2969  data: 0.0111  max mem: 3888
# Test:  [2300/2506]  eta: 0:01:00  model_time: 0.2545 (0.2750)  evaluator_time: 0.0037 (0.0056)  time: 0.2819  data: 0.0105  max mem: 3888
# Test:  [2400/2506]  eta: 0:00:31  model_time: 0.2757 (0.2748)  evaluator_time: 0.0049 (0.0056)  time: 0.3019  data: 0.0114  max mem: 3888
# Test:  [2500/2506]  eta: 0:00:01  model_time: 0.2570 (0.2748)  evaluator_time: 0.0047 (0.0056)  time: 0.2932  data: 0.0112  max mem: 3888
# Test:  [2505/2506]  eta: 0:00:00  model_time: 0.2569 (0.2748)  evaluator_time: 0.0044 (0.0056)  time: 0.2864  data: 0.0109  max mem: 3888
# Test: Total time: 0:12:14 (0.2929 s / it)
# Averaged stats: model_time: 0.2569 (0.2748)  evaluator_time: 0.0044 (0.0056)
# Accumulating evaluation results...
# DONE (t=1.92s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.166
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.534

# %%
model = torch.load('/content/gdrive/MyDrive/CElossRetinaNet33.pth')
model=model.to(dev)
evaluate(model,test_loader,dev)
# Out:
# creating index...
# index created!
# Test:  [   0/2506]  eta: 0:14:01  model_time: 0.3170 (0.3170)  evaluator_time: 0.0048 (0.0048)  time: 0.3360  data: 0.0128  max mem: 3888
# Test:  [ 100/2506]  eta: 0:11:47  model_time: 0.2721 (0.2767)  evaluator_time: 0.0037 (0.0048)  time: 0.3112  data: 0.0110  max mem: 3888
# Test:  [ 200/2506]  eta: 0:11:21  model_time: 0.2556 (0.2777)  evaluator_time: 0.0037 (0.0053)  time: 0.2983  data: 0.0108  max mem: 3888
# Test:  [ 300/2506]  eta: 0:10:43  model_time: 0.2438 (0.2741)  evaluator_time: 0.0040 (0.0051)  time: 0.2723  data: 0.0109  max mem: 3888
# Test:  [ 400/2506]  eta: 0:10:14  model_time: 0.2577 (0.2741)  evaluator_time: 0.0042 (0.0055)  time: 0.2858  data: 0.0110  max mem: 3888
# Test:  [ 500/2506]  eta: 0:09:47  model_time: 0.2618 (0.2750)  evaluator_time: 0.0041 (0.0054)  time: 0.2950  data: 0.0109  max mem: 3888
# Test:  [ 600/2506]  eta: 0:09:18  model_time: 0.2586 (0.2754)  evaluator_time: 0.0036 (0.0053)  time: 0.2972  data: 0.0112  max mem: 3888
# Test:  [ 700/2506]  eta: 0:08:47  model_time: 0.2552 (0.2745)  evaluator_time: 0.0045 (0.0053)  time: 0.2800  data: 0.0109  max mem: 3888
# Test:  [ 800/2506]  eta: 0:08:19  model_time: 0.2541 (0.2750)  evaluator_time: 0.0035 (0.0053)  time: 0.2855  data: 0.0108  max mem: 3888
# Test:  [ 900/2506]  eta: 0:07:51  model_time: 0.2659 (0.2752)  evaluator_time: 0.0043 (0.0054)  time: 0.3013  data: 0.0107  max mem: 3888
# Test:  [1000/2506]  eta: 0:07:21  model_time: 0.2882 (0.2754)  evaluator_time: 0.0044 (0.0054)  time: 0.3178  data: 0.0107  max mem: 3888
# Test:  [1100/2506]  eta: 0:06:51  model_time: 0.2591 (0.2749)  evaluator_time: 0.0044 (0.0054)  time: 0.2958  data: 0.0110  max mem: 3888
# Test:  [1200/2506]  eta: 0:06:23  model_time: 0.2611 (0.2754)  evaluator_time: 0.0046 (0.0054)  time: 0.2908  data: 0.0114  max mem: 3888
# Test:  [1300/2506]  eta: 0:05:54  model_time: 0.2528 (0.2757)  evaluator_time: 0.0057 (0.0054)  time: 0.2981  data: 0.0110  max mem: 3888
# Test:  [1400/2506]  eta: 0:05:25  model_time: 0.2538 (0.2759)  evaluator_time: 0.0044 (0.0054)  time: 0.2994  data: 0.0113  max mem: 3888
# Test:  [1500/2506]  eta: 0:04:55  model_time: 0.2566 (0.2755)  evaluator_time: 0.0040 (0.0054)  time: 0.2860  data: 0.0110  max mem: 3888
# Test:  [1600/2506]  eta: 0:04:25  model_time: 0.2533 (0.2751)  evaluator_time: 0.0039 (0.0054)  time: 0.2801  data: 0.0112  max mem: 3888
# Test:  [1700/2506]  eta: 0:03:56  model_time: 0.2536 (0.2751)  evaluator_time: 0.0037 (0.0054)  time: 0.2867  data: 0.0115  max mem: 3888
# Test:  [1800/2506]  eta: 0:03:26  model_time: 0.2633 (0.2752)  evaluator_time: 0.0036 (0.0053)  time: 0.2986  data: 0.0107  max mem: 3888
# Test:  [1900/2506]  eta: 0:02:57  model_time: 0.2588 (0.2755)  evaluator_time: 0.0043 (0.0054)  time: 0.2897  data: 0.0111  max mem: 3888
# Test:  [2000/2506]  eta: 0:02:28  model_time: 0.2550 (0.2756)  evaluator_time: 0.0042 (0.0053)  time: 0.2892  data: 0.0110  max mem: 3888
# Test:  [2100/2506]  eta: 0:01:59  model_time: 0.2617 (0.2755)  evaluator_time: 0.0037 (0.0054)  time: 0.2978  data: 0.0107  max mem: 3888
# Test:  [2200/2506]  eta: 0:01:29  model_time: 0.2615 (0.2755)  evaluator_time: 0.0041 (0.0054)  time: 0.2990  data: 0.0110  max mem: 3888
# Test:  [2300/2506]  eta: 0:01:00  model_time: 0.2554 (0.2751)  evaluator_time: 0.0037 (0.0054)  time: 0.2817  data: 0.0106  max mem: 3888
# Test:  [2400/2506]  eta: 0:00:31  model_time: 0.2780 (0.2749)  evaluator_time: 0.0052 (0.0054)  time: 0.3032  data: 0.0115  max mem: 3888
# Test:  [2500/2506]  eta: 0:00:01  model_time: 0.2596 (0.2750)  evaluator_time: 0.0044 (0.0054)  time: 0.2949  data: 0.0113  max mem: 3888
# Test:  [2505/2506]  eta: 0:00:00  model_time: 0.2574 (0.2749)  evaluator_time: 0.0044 (0.0054)  time: 0.2876  data: 0.0111  max mem: 3888
# Test: Total time: 0:12:13 (0.2928 s / it)
# Averaged stats: model_time: 0.2574 (0.2749)  evaluator_time: 0.0044 (0.0054)
# Accumulating evaluation results...
# DONE (t=1.85s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.698
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.438
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.551

# %%
model = torch.load('/content/gdrive/MyDrive/CElossRetinaNet34.pth')
model=model.to(dev)
evaluate(model,test_loader,dev)
# Out:
# creating index...
# index created!
# Test:  [   0/2506]  eta: 0:12:47  model_time: 0.2860 (0.2860)  evaluator_time: 0.0071 (0.0071)  time: 0.3062  data: 0.0116  max mem: 3888
# Test:  [ 100/2506]  eta: 0:10:46  model_time: 0.2418 (0.2508)  evaluator_time: 0.0039 (0.0053)  time: 0.2764  data: 0.0112  max mem: 3888
# Test:  [ 200/2506]  eta: 0:10:29  model_time: 0.2514 (0.2547)  evaluator_time: 0.0041 (0.0058)  time: 0.2894  data: 0.0112  max mem: 3888
# Test:  [ 300/2506]  eta: 0:10:07  model_time: 0.2399 (0.2573)  evaluator_time: 0.0043 (0.0057)  time: 0.2683  data: 0.0111  max mem: 3888
# Test:  [ 400/2506]  eta: 0:09:45  model_time: 0.2463 (0.2594)  evaluator_time: 0.0045 (0.0060)  time: 0.2757  data: 0.0112  max mem: 3888
# Test:  [ 500/2506]  eta: 0:09:22  model_time: 0.2584 (0.2620)  evaluator_time: 0.0046 (0.0060)  time: 0.2936  data: 0.0113  max mem: 3888
# Test:  [ 600/2506]  eta: 0:08:58  model_time: 0.2577 (0.2644)  evaluator_time: 0.0038 (0.0058)  time: 0.2977  data: 0.0112  max mem: 3888
# Test:  [ 700/2506]  eta: 0:08:32  model_time: 0.2590 (0.2654)  evaluator_time: 0.0047 (0.0058)  time: 0.2835  data: 0.0113  max mem: 3888
# Test:  [ 800/2506]  eta: 0:08:06  model_time: 0.2531 (0.2669)  evaluator_time: 0.0041 (0.0058)  time: 0.2858  data: 0.0111  max mem: 3888
# Test:  [ 900/2506]  eta: 0:07:40  model_time: 0.2672 (0.2680)  evaluator_time: 0.0048 (0.0059)  time: 0.3034  data: 0.0108  max mem: 3888
# Test:  [1000/2506]  eta: 0:07:12  model_time: 0.2858 (0.2690)  evaluator_time: 0.0047 (0.0060)  time: 0.3196  data: 0.0107  max mem: 3888
# Test:  [1100/2506]  eta: 0:06:44  model_time: 0.2575 (0.2693)  evaluator_time: 0.0045 (0.0059)  time: 0.2971  data: 0.0112  max mem: 3888
# Test:  [1200/2506]  eta: 0:06:16  model_time: 0.2543 (0.2700)  evaluator_time: 0.0043 (0.0059)  time: 0.2870  data: 0.0113  max mem: 3888
# Test:  [1300/2506]  eta: 0:05:48  model_time: 0.2600 (0.2708)  evaluator_time: 0.0064 (0.0060)  time: 0.3030  data: 0.0113  max mem: 3888
# Test:  [1400/2506]  eta: 0:05:20  model_time: 0.2630 (0.2714)  evaluator_time: 0.0048 (0.0060)  time: 0.3024  data: 0.0112  max mem: 3888
# Test:  [1500/2506]  eta: 0:04:51  model_time: 0.2567 (0.2713)  evaluator_time: 0.0045 (0.0059)  time: 0.2861  data: 0.0112  max mem: 3888
# Test:  [1600/2506]  eta: 0:04:22  model_time: 0.2560 (0.2712)  evaluator_time: 0.0040 (0.0059)  time: 0.2821  data: 0.0113  max mem: 3888
# Test:  [1700/2506]  eta: 0:03:53  model_time: 0.2465 (0.2714)  evaluator_time: 0.0042 (0.0059)  time: 0.2870  data: 0.0113  max mem: 3888
# Test:  [1800/2506]  eta: 0:03:24  model_time: 0.2660 (0.2717)  evaluator_time: 0.0041 (0.0059)  time: 0.2996  data: 0.0108  max mem: 3888
# Test:  [1900/2506]  eta: 0:02:56  model_time: 0.2575 (0.2722)  evaluator_time: 0.0044 (0.0059)  time: 0.2899  data: 0.0110  max mem: 3888
# Test:  [2000/2506]  eta: 0:02:27  model_time: 0.2583 (0.2725)  evaluator_time: 0.0046 (0.0059)  time: 0.2917  data: 0.0111  max mem: 3888
# Test:  [2100/2506]  eta: 0:01:58  model_time: 0.2613 (0.2725)  evaluator_time: 0.0038 (0.0060)  time: 0.2985  data: 0.0106  max mem: 3888
# Test:  [2200/2506]  eta: 0:01:29  model_time: 0.2585 (0.2727)  evaluator_time: 0.0041 (0.0060)  time: 0.2968  data: 0.0110  max mem: 3888
# Test:  [2300/2506]  eta: 0:00:59  model_time: 0.2529 (0.2724)  evaluator_time: 0.0038 (0.0061)  time: 0.2829  data: 0.0107  max mem: 3888
# Test:  [2400/2506]  eta: 0:00:30  model_time: 0.2785 (0.2723)  evaluator_time: 0.0051 (0.0061)  time: 0.3030  data: 0.0115  max mem: 3888
# Test:  [2500/2506]  eta: 0:00:01  model_time: 0.2577 (0.2723)  evaluator_time: 0.0048 (0.0061)  time: 0.2930  data: 0.0111  max mem: 3888
# Test:  [2505/2506]  eta: 0:00:00  model_time: 0.2574 (0.2723)  evaluator_time: 0.0048 (0.0061)  time: 0.2856  data: 0.0110  max mem: 3888
# Test: Total time: 0:12:09 (0.2909 s / it)
# Averaged stats: model_time: 0.2574 (0.2723)  evaluator_time: 0.0048 (0.0061)
# Accumulating evaluation results...
# DONE (t=2.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.704
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.442
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.554

# %%
model = torch.load('/content/gdrive/MyDrive/CElossRetinaNet36.pth')
model=model.to(dev)
evaluate(model,test_loader,dev)
# Out:
# creating index...
# index created!
# Test:  [   0/2506]  eta: 0:13:30  model_time: 0.3033 (0.3033)  evaluator_time: 0.0063 (0.0063)  time: 0.3233  data: 0.0123  max mem: 4136
# Test:  [ 100/2506]  eta: 0:11:52  model_time: 0.2768 (0.2793)  evaluator_time: 0.0039 (0.0047)  time: 0.3155  data: 0.0114  max mem: 4136
# Test:  [ 200/2506]  eta: 0:11:21  model_time: 0.2611 (0.2782)  evaluator_time: 0.0038 (0.0051)  time: 0.2986  data: 0.0109  max mem: 4136
# Test:  [ 300/2506]  eta: 0:10:43  model_time: 0.2438 (0.2743)  evaluator_time: 0.0038 (0.0049)  time: 0.2706  data: 0.0109  max mem: 4136
# Test:  [ 400/2506]  eta: 0:10:14  model_time: 0.2564 (0.2744)  evaluator_time: 0.0040 (0.0051)  time: 0.2842  data: 0.0108  max mem: 4136
# Test:  [ 500/2506]  eta: 0:09:47  model_time: 0.2615 (0.2752)  evaluator_time: 0.0045 (0.0051)  time: 0.2988  data: 0.0114  max mem: 4136
# Test:  [ 600/2506]  eta: 0:09:18  model_time: 0.2620 (0.2755)  evaluator_time: 0.0034 (0.0050)  time: 0.2987  data: 0.0111  max mem: 4136
# Test:  [ 700/2506]  eta: 0:08:47  model_time: 0.2576 (0.2747)  evaluator_time: 0.0043 (0.0050)  time: 0.2810  data: 0.0111  max mem: 4136
# Test:  [ 800/2506]  eta: 0:08:19  model_time: 0.2534 (0.2751)  evaluator_time: 0.0037 (0.0050)  time: 0.2869  data: 0.0111  max mem: 4136
# Test:  [ 900/2506]  eta: 0:07:50  model_time: 0.2639 (0.2754)  evaluator_time: 0.0041 (0.0051)  time: 0.3016  data: 0.0106  max mem: 4136
# Test:  [1000/2506]  eta: 0:07:21  model_time: 0.2891 (0.2756)  evaluator_time: 0.0041 (0.0051)  time: 0.3171  data: 0.0107  max mem: 4136
# Test:  [1100/2506]  eta: 0:06:51  model_time: 0.2597 (0.2753)  evaluator_time: 0.0042 (0.0051)  time: 0.2970  data: 0.0111  max mem: 4136
# Test:  [1200/2506]  eta: 0:06:22  model_time: 0.2569 (0.2758)  evaluator_time: 0.0040 (0.0051)  time: 0.2880  data: 0.0111  max mem: 4136
# Test:  [1300/2506]  eta: 0:05:54  model_time: 0.2576 (0.2762)  evaluator_time: 0.0056 (0.0051)  time: 0.3001  data: 0.0111  max mem: 4136
# Test:  [1400/2506]  eta: 0:05:24  model_time: 0.2585 (0.2763)  evaluator_time: 0.0042 (0.0051)  time: 0.3012  data: 0.0114  max mem: 4136
# Test:  [1500/2506]  eta: 0:04:55  model_time: 0.2563 (0.2759)  evaluator_time: 0.0040 (0.0051)  time: 0.2861  data: 0.0115  max mem: 4136
# Test:  [1600/2506]  eta: 0:04:25  model_time: 0.2545 (0.2755)  evaluator_time: 0.0037 (0.0051)  time: 0.2809  data: 0.0113  max mem: 4136
# Test:  [1700/2506]  eta: 0:03:56  model_time: 0.2468 (0.2755)  evaluator_time: 0.0038 (0.0051)  time: 0.2866  data: 0.0116  max mem: 4136
# Test:  [1800/2506]  eta: 0:03:26  model_time: 0.2589 (0.2756)  evaluator_time: 0.0037 (0.0051)  time: 0.2971  data: 0.0107  max mem: 4136
# Test:  [1900/2506]  eta: 0:02:57  model_time: 0.2638 (0.2758)  evaluator_time: 0.0038 (0.0051)  time: 0.2905  data: 0.0111  max mem: 4136
# Test:  [2000/2506]  eta: 0:02:28  model_time: 0.2590 (0.2759)  evaluator_time: 0.0039 (0.0051)  time: 0.2907  data: 0.0110  max mem: 4136
# Test:  [2100/2506]  eta: 0:01:59  model_time: 0.2625 (0.2758)  evaluator_time: 0.0033 (0.0051)  time: 0.2967  data: 0.0105  max mem: 4136
# Test:  [2200/2506]  eta: 0:01:29  model_time: 0.2630 (0.2758)  evaluator_time: 0.0039 (0.0051)  time: 0.2973  data: 0.0109  max mem: 4136
# Test:  [2300/2506]  eta: 0:01:00  model_time: 0.2552 (0.2755)  evaluator_time: 0.0038 (0.0051)  time: 0.2833  data: 0.0108  max mem: 4136
# Test:  [2400/2506]  eta: 0:00:31  model_time: 0.2673 (0.2753)  evaluator_time: 0.0046 (0.0051)  time: 0.3018  data: 0.0114  max mem: 4136
# Test:  [2500/2506]  eta: 0:00:01  model_time: 0.2558 (0.2753)  evaluator_time: 0.0041 (0.0052)  time: 0.2917  data: 0.0112  max mem: 4136
# Test:  [2505/2506]  eta: 0:00:00  model_time: 0.2539 (0.2752)  evaluator_time: 0.0042 (0.0052)  time: 0.2850  data: 0.0112  max mem: 4136
# Test: Total time: 0:12:14 (0.2930 s / it)
# Averaged stats: model_time: 0.2539 (0.2752)  evaluator_time: 0.0042 (0.0052)
# Accumulating evaluation results...
# DONE (t=1.72s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.699
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.177
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.244
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
